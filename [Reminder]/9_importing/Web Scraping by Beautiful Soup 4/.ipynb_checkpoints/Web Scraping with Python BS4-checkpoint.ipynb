# %% [markdown]
# # Beautiful Soup Tutorial - Web Scraping with Python

# %%
import pandas as pd
import os
from bs4 import BeautifulSoup

# %% [markdown]
# ## Reading HTML Files

# %%
with open('index.html', 'r') as file: 
    doc = BeautifulSoup(file, 'html.parser')

print(doc)
# Out:
# <html>
# <head>
# <title>Your Title Here</title>
# </head>
# <body bgcolor="FFFFFF">
# <center><img align="BOTTOM" src="clouds.jpg"/> </center>
# <hr/>
# <a href="http://somegreatsite.com">Link Name</a>
#
#   is a link to another nifty site
#
#   <h1>This is a Header</h1>
# <h2>This is a Medium Header</h2>
#
#   Send me mail at <a href="mailto:support@yourcompany.com">
#
#   support@yourcompany.com</a>.
#
#   <p> This is a new paragraph!
#
#   <p> <b color="red">This is a new paragraph!</b>
# <br/> <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
# <hr/>
# </p></p></body>
# </html>

# %%
print(doc.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Your Title Here
#   </title>
#  </head>
#  <body bgcolor="FFFFFF">
#   <center>
#    <img align="BOTTOM" src="clouds.jpg"/>
#   </center>
#   <hr/>
#   <a href="http://somegreatsite.com">
#    Link Name
#   </a>
#   is a link to another nifty site
#   <h1>
#    This is a Header
#   </h1>
#   <h2>
#    This is a Medium Header
#   </h2>
#   Send me mail at
#   <a href="mailto:support@yourcompany.com">
#    support@yourcompany.com
#   </a>
#   .
#   <p>
#    This is a new paragraph!
#   </p>
#   <p>
#    <b color="red">
#     This is a new paragraph!
#    </b>
#    <br/>
#    <b>
#     <i>
#      This is a new sentence without a paragraph break, in bold italics.
#     </i>
#    </b>
#   </p>
#   <hr/>
#  </body>
# </html>

# %% [markdown]
# ## Find by the Tag Name
#
# Using `.<tag_name>` you can access to the first tag that has this name in the document. This method is identical to `.find('tag_name')`

# %%
tag = doc.title
print(tag)
# Out:
# <title>Your Title Here</title>

# %% [markdown]
# To access the content or the string inside the tag, we can use `.string`

# %%
print(tag.string)
# Out:
# Your Title Here

# %% [markdown]
# The same way we can access things, we also can change it.

# %%
tag.string = 'hello'
print(doc)
# Out:
# <html>
# <head>
# <title>hello</title>
# </head>
# <body bgcolor="FFFFFF">
# <center><img align="BOTTOM" src="clouds.jpg"/> </center>
# <hr/>
# <a href="http://somegreatsite.com">Link Name</a>
#
#   is a link to another nifty site
#
#   <h1>This is a Header</h1>
# <h2>This is a Medium Header</h2>
#
#   Send me mail at <a href="mailto:support@yourcompany.com">
#
#   support@yourcompany.com</a>.
#
#   <p> This is a new paragraph!
#
#   </p><p> <b color="red">This is a new paragraph!</b>
# <br/> <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
# </p><hr/>
# </body>
# </html>

# %% [markdown]
# ## Find All by Tag Name
#
# `.find_all(<tag_name>)` will give you all the tags in the document.

# %%
tags = doc.find_all('p')
print(tags)
# Out:
# [<p> This is a new paragraph!
#
#   </p>, <p> <b color="red">This is a new paragraph!</b>
# <br/> <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
# </p>]

# %% [markdown]
# Notice that the `<p>` tag has things like tags again inside of them, right? We can access the nested tags using a combination of list indexing and `.find_all` function again.

# %%
print(tags[1])
print()
print(tags[1].find_all('b'))
# Out:
# <p> <b color="red">This is a new paragraph!</b>
# <br/> <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
# </p>
#
# [<b color="red">This is a new paragraph!</b>, <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>]

# %% [markdown]
# ## Parsing Website HTML

# %%
import requests

url = "https://www.newegg.ca/black-logitech-g-pro-x/p/N82E16826197345?Item=N82E16826197345"
result = requests.get(url)
print(result.text)
# Out:
# <!DOCTYPE html><html lang="en-ca" class="show-tab-store"><head><title>Logitech G Pro X Gaming Headset - Newegg.ca</title><meta charSet="utf-8"/><meta http-equiv="content-type" content="text/html; charset=UTF-8"/><meta name="referrer" content="always"/><meta name="keywords" content="Newegg, Newegg.ca, Logitech G Pro X Gaming Headset"/><meta name="description" content="Buy Logitech G Pro X Gaming Headset with fast shipping and top-rated customer service.Once you know, you Newegg!"/><meta property="og:image" content="https://c1.neweggimages.com/ProductImage/26-197-345-V09.jpg"/><meta property="og:description" content="Buy Logitech G Pro X Gaming Headset with fast shipping and top-rated customer service. Once you know, you Newegg!"/><meta property="og:title" content="Logitech G Pro X Gaming Headset - Newegg.com"/><meta property="og:url" content="https://www.newegg.ca/black-logitech-g-pro-x/p/N82E16826197345"/><meta property="og:type" content="website"/><meta name="language" content="english"/><meta name="copyright" content="© 2000-2022 Newegg Inc."/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="robots" content="index,follow,max-image-preview:large,max-snippet:-1"/><meta name="X-DNS-Prefetch-Control" content="on"/><meta name="format-detection" content="telephone=no"/><link rel="shortcut icon" type="image/x-icon" href="https://c1.neweggimages.com/WebResource/ngm/newegg.ico"/><link rel="canonical" href="https://www.newegg.ca/black-logitech-g-pro-x/p/N82E16826197345"/><link rel="amphtml" href="https://www.newegg.ca/amp/black-logitech-g-pro-x/p/N82E16826197345"/><script>window.__PolyfillScripts__={"core-js":"https://c1.neweggimages.com/WebResource/Scripts/WWW/core-js.polyfill.min.js","intersection-observer":"https://c1.neweggimages.com/WebResource/Scripts/WWW/intersection-observer.polyfill.min.js"}</script><script src="https://c1.neweggimages.com/WebResource/Scripts/WWW/runtime~product~ProductDetail-bbb73a14.js"></script><script src="https://c1.neweggimages.com/WebResource/Scripts/WWW/polyfillEntry-0cbc9230.js"></script><link href="https://c1.neweggimages.com/WebResource/Themes/WWW/CSS/vendor~product~ProductDetail-da1cae6dca5b287aef51.css" rel="stylesheet"/><link href="https://c1.neweggimages.com/WebResource/Themes/WWW/CSS/ProductDetail-162534606c4e18ab6e15.css" rel="stylesheet"/><script id="kimoi" type="application/json">[{"type":"setCookie","payload":{"cookie":"CountryRegion","value":"CAN"}},{"type":"setCookie","payload":{"cookie":"LanguageCode","value":"en"}},{"type":"setSubCookie","payload":{"cookie":"CountryConfiguration","subCookieKey":"CurrencyCode","subCookieValue":"CAD"}}]</script></head><body><div><script type="text/javascript">;;;(function(){var e=document.querySelector('meta[name="viewport"]'),t=document.createElement("meta");t.name="viewport",t.content="width=device-width",e||document.head.appendChild(t)})();</script></div><div><script type="text/javascript">var nebs=nebs||{};nebs.errors=[];window.onerror=function(){nebs.errors.push(arguments);return true;}</script></div><div><script src="https://c1.neweggimages.com/webResource/Scripts/WWW/jquery-3.5.1.min.js"></script></div><div><script>!function(){var style = document.createElement('style');style.type = 'text/css';style.innerHTML=document.getElementById('NewTemplate')?'div.grid-col.radius-m.bg-white.our-apps > div.line-horizontal.bg-line.width-auto > span{color:#4D4D4D}.sticky-header-top body{padding-top:115px;height:auto;min-height:calc(100% - 115px);} .sticky-header-top .page-content{padding-top:0;min-height:0;}':'@import url(https://c1.neweggimages.com/webresource/themes/darkmode-min.28.css);.dark-mode #ot-sdk-btn.ot-sdk-show-settings, .dark-mode #ot-sdk-btn.optanon-show-settings{ color: #e3e3e3 !important }.dark-mode #ot-sdk-btn.ot-sdk-show-settings:hover, .dark-mode #ot-sdk-btn.optanon-show-settings:hover{color: #ea9d28 !important;};.footer2021-disclaimer-link:hover {color: #e3e3e3!important;} div.grid-col.radius-m.bg-white.our-apps > div.line-ho ...
# <script type="text/javascript">(function(){var darkv = document.cookie.match('(^|;) ?NV_Theme=([^;]*)(;|$)');var dark = darkv ? darkv[2] : "false";if (dark == "true") {if(!document.getElementById('NewTemplate')){jQuery('html').addClass('dark-mode');}else{document.documentElement.classList.add("dark-mode")}}var style = document.createElement("style");var darkCss='#Dark_Mode{display:none;}.header2021-toggle{z-index:5}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:20px}.header2021-toggle:hover{transform:scale(1)}.header2021-toggle:hover .bg-lightgray{background-color:rgba(235,235,235,1)}.header2021-toggle .toggle-body{border:1px solid #212121;border-radius:30px}.header2021-toggle .toggle-body-inner:after{border-radius:30px;width:30px;top:0;bottom:0;margin-left:-1px;box-shadow:0 1px 6px 0 rgb(0 0 0 / 16%)}.header2021-toggle .toggle-handle{font-size:20px;color:#474747}.header2021-toggle .dark-mode-tooltip{padding:5px 15px;white-space:nowrap}.header2021-toggle.menu.at-bottom .menu-body{left:auto;right:0;margin-top:12px;text-align:left}.header2021-toggle.at-bottom>.menu-arrow{left:auto;right:20px;text-align:left}.header2021-toggle.at-bottom>.menu-body>.menu-arrow{left:auto!important;right:20px}.dark-mode .header2021-toggle .toggle-handle.take-on{padding-left:8px}.dark-mode .header2021-toggle:hover .bg-lightgray{background-color:#ea7421}.dark-mode .header2021-toggle .toggle-body{border:1px solid #835b38}.dark-mode .header2021-toggle .bg-lightgray{background-color:#e05d00}.dark-mode .header2021-toggle input[type="checkbox"]:checked ~ .toggle-body .toggle-body-inner:after{margin-right:0;margin-left:0;top:0}.dark-mode .header2021-toggle .toggle-body-inner:after{box-shadow:0 6px 6px 0 rgb(0 0 0 / 16%)}@media(max-width:599px){.header2021-inner{padding:15px 2px}.header2021-logo{width:60px}.header2021-country.header2021-nav:not(:first-child){margin-left:15px}.header2021-toggle .bg-lightgray{background:#fff}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:15px}.header2021-toggle .toggle-body{min-width:30px;height:30px;border-radius:50%}.header2021-toggle .toggle-body-inner{width:100%;height:100%;transform:translateX(0);justify-content:center;align-items:center}.header2021-toggle .toggle-handle{height:100%;line-height:1.1;padding:0;font-size:22px;justify-content:center;z-index:2}.header2021-toggle .toggle-body-inner:after{content:none}.header2021-toggle .toggle-handle.take-off{padding:0}.header2021-toggle .toggle-handle.take-on,.header2021-toggle.menu.at-bottom .menu-body{display:none}.dark-mode .header2021-toggle .toggle-handle.take-on{display:flex;padding:0}.dark-mode .header2021-toggle .toggle-handle.take-off{display:none}.section-right>.line-vertical-new{margin:0 0 0 10px}}@media(max-width:350px){.header2021-nav-inner,.header2021-nav.menu .header2021-nav-inner{padding-left:26px;height:26px;min-height:26px}.header2021-country-flag{width:26px;height:26px}.header2021-nav-icon{width:26px;height:26px;line-height:26px;font-size:24px;top:2px}.header2021-nav ~ .header2021-nav{margin-left:5px}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:10px}.header2021-toggle .toggle-body{min-width:24px;height:24px}.header2021-toggle .toggle-handle{font-size:16px}}';try{style.appendChild(document.createTextNode(darkCss));}catch(ex){style.styleSheet.cssText = darkCss;}var head = document.getElementsByTagName("head")[0];head&&head.appendChild(style);var darkbut = jQuery('<div class="header2021-nav header2021-toggle toggle toggle-m menu at-bottom"><label id="darkLabel"><input type="checkbox" id="checkdarkmode"><span class="toggle-body bg-lightgray font-l"><span class="toggle-body-inner"><span class="toggle-handle take-on">&#9790;</span><span class="toggle-handle take-off ">&#9728;</span></span></span></label><div id="darkModal" class="menu-body bg-white radius-s shadow-level-1"><i class="menu-arrow"></i><p class="dark-mode-tooltip">Switch to Dark Mode</p></div></div>');jQuery(document).ready(function (){jQuery('.head ...
# </div><div><script type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-W26F4QT');</script></div><div><style>@import url(https://c1.neweggimages.com/webresource/themes/WWW/CSS/fixManufactory.css)</style></div><div> <script type="text/javascript" src="https://c1.neweggimages.com/webresource/Scripts/Others/TopRatedSeller/new-feature-script.2.0.5.min.js" defer></script></div><div>
#             <script type="text/javascript">
#             ;;;(function() {
#                 window.__ga_forbiddenList = null;
#                 window.__ga_mappingAdobe = [{
#                     events:["event63"],
#                     eventName:"click_event",
#                     mapping:{
#                         links:"evar78"
#                     }
#                 }];
#                 window.__ga_linkInternalFilters = "javascript:,newegg.com,gamecrate.com,abs.com,checkout.us.zip.co,zip.co,checkout.quadpay.com,3debspay.boc.cn,alfabank.ru,arcot.com,billmelater.com,citibank.co.kr,ftpsllc.com,garanti.com.tr,hyundaicard.com,kbcard.com,keb.co.kr,masterpass.com,mycardsecure.com,newegg3.com.sh,paypal.com,samsungcard.co.kr,secure2gw.ro,securecode.com,secureserver.net,securesuite.co.uk,securesuite.net,shinhancard.com,verifiedbyvisa.com,visa.com,visa.com.ar,web.v.me,secondfunnel.com,cardinalcommerce.com,secure.neweggbusiness.com,www-newegg-com.cdn.ampproject.org,www.newegg.ca,secure.newegg.ca,kb.neweggbusiness.com,www.neweggbusiness.com,help.newegg.ca,secure.m.newegg.ca,secure.newegg.com,www.rosewill.com,neweggbusiness.com,sellerportal.newegg.cn,partner.gqc.newegg.space,help.neweggbusiness.com,secure.newegg6.com.sh,sellerportal62780.gqc.newegg.space,central3.newegg.org,partner.newegg.cn,secure.newegg4.com.sh,newegg.io,newegggpu.com,justgpu.com";
#             })()
#         </script>
#             </div><div id="app"><header class="header2021 bg-white"><div class="page-content-inner"><div class="header2021-inner"><div class="section-left auto-flex"><div><div class="header2021-hamburger-new header2021-hamburger menu at-bottom"><i class="header2021-hamburger-icon ico ico-bars bg-transparent-gray" aria-label="Site Menu"></i></div></div><div class="header2021-logo"><a href="https://www.newegg.ca/" class="header2021-logo-img" title="Newegg.ca - Computer Parts, Laptops, Electronics, HDTVs, Digital Cameras and More!"><img src="https://c1.neweggimages.com/WebResource/Themes/Nest/logos/Newegg_full_color_logo_RGB.SVG" alt="Newegg"/></a></div><div class="header2021-nav header2021-location  menu at-bottom"><a href="#" class="header2021-nav-inner bg-transparent-gray" title="Select address "><i class="ico ico-map-marker header2021-nav-icon" aria-label="icon of my location"></i><div class="header2021-nav-title text-gray font-s">Hello<!-- --> <span class="header2021-info-nowrap header2021-info-min"></span></div><div class="header2021-nav-subtitle"><span class="">Select address</span> <span></span></div></a></div><div class="header2021-search auto-flex"><div class="header2021-search-inner"><div class="header2021-search-box auto-flex"><input type="search" title="Search Site" autoComplete="off" value=""/></div><div class="header2021-search-button"><button class="ico ico-search"><span class="display-none">Search</span></button></div></div></div></div><div class="section-right"><div class="header2021-nav  header2021-country menu at-bottom"><a title="Change Country" class="header2021-country-flag bg-transparent-gray"><i class="flag ca"></i><span class="display-none">Change Country</span></a></div><div class="nav-complex"><a href="https://secure.newegg.ca/login/signin?nextpage=" class="header2021-nav-inner bg-transparent-gray" title="My Account"><i class="ico ico-user header2021-nav-icon" aria-label="icon of my account"></i></a></div><div class="header2021-nav header2021-returns s-hide"><a href="https://secure.newegg.ca/orders/list" class="header2021-nav-inner bg-transparent-gray" title="Orders"><div class="header2021-nav-title text-gray font-s"><span>Returns</span></div><div class="header2021-nav-subtitle">&amp; Orders</div></a></div><div class="header2021-nav header2021-cart"><a href="https://secure.newegg.ca/shop/cart" class="header2021-nav-inner bg-transparent-gray" title="Shopping Cart" aria-label="Shopping Cart"><i class="ico ico-shopping-cart header2021-nav-icon" aria-label="icon of shopping cart"></i></a></div></div></div><div class="header2021-inner"><div class="section-left auto-flex"><div id="Portals_swiper" class="header2021-portals"><div class="swiper-container swiper-container-horizontal"><div class="swiper-wrapper"><div class="swiper-slide"></div><div class="swiper-slide"><a class="header2021-portal" id="trendingBanner_733797" href="////www.newegg.ca/promotions/nepro/22-1968/index.html?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Black+Friday+Ads&icid=733797" title="Black Friday Ads" "><span class="font-s">Black Friday Ads</span></a></div><div class="swiper-slide"><a class="header2021-portal" id="trendingBanner_726849" href="////www.newegg.ca/Spotlight/Store/ID-14?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Spotlight&icid=726849" title="Spotlight" "><span class="font-s">Spotlight</span></a></div><div class="swiper-slide"><a class="header2021-portal" id="trendingBanner_623097" href="////www.newegg.ca/d/best-sellers?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Best+Sellers&icid=623097" title="Best Sellers" "><span class="font-s">Best Sellers</span></a></div><div class="swiper-slide"><a class="header2021-portal" id="trendingBanner_649302" href="////www.newegg.ca/Elite-Deals/EventSaleStore/ID-779?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Elite+Deals&icid=649302" title="Elite Deals" "><span class="font-s">Elite Deals</span></a></div><div class="swiper-slide"><a class="header2021-portal" id="trendingBanner_732631" href="////w ...
#                             id="trendingBanner_649759"
#                             href="//www.newegg.ca/d/browsing-history?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Browsing+History&icid=649759" title="Browsing History"
#                             class="header2021-portal"
#                           ">
#                           <span class="font-s">
#                                 Browsing History
#                                 </span>
#                                 <i class="ico ico-angle-down" aria-label="dropdown"></i>
#                                 <div class="menu-arrow"></div>
# </li><li>Detachable 6mm Mic+ - Large mic for amazingly clear voice comms</li></ul></div><div class="product-msg-group"></div></div></div><div class="product-contents"><div class="page-section"><div class="page-section-inner"><div id="PDP_product-recommend"></div><div id="product-details" class="tab-box"><div class="tab-navs"><div class="tab-nav active">Overview</div><div class="tab-nav">Specs</div><div class="tab-nav">Reviews</div></div><div class="tab-panes"><div class="tab-pane" style="display:block"><div id="product-overview" class="article"><div><div id="wc-power-page"></div><script type="text/javascript" provider="Webcollage">(function(){    var loadContent = function () {        window.Webcollage.loadContent(            "newegg",            "9SIANZYBGY3020",            { reload: true }        );    };    if (window.Webcollage) {        loadContent();    } else {        var script = document.createElement('script');         script.type = 'text/javascript';        script.async = true;         script.src = "https://scontent.webcollage.net/api/v2/product-content";        if (script.addEventListener) script.addEventListener('load', loadContent);        if (script.attachEvent) script.attachEvent('onload', loadContent);        document.head.appendChild(script);    }}());</script></div></div></div><div class="tab-pane" style="display:none"><h2 class="swiper-box-top-title margin-bottom">Learn more about the <!-- -->Logitech G Pro X</h2><table class="table-horizontal"><caption></caption><tbody><tr><th>Best Seller Ranking<!-- --> </th><td>#2 in <a href=https://www.newegg.ca/d/Best-Sellers/Gaming-Headsets/s/ID-3767 onclick="Biz.Common.SiteCatalyst.sendForOnClick({events: 'event63',eVar78: 'product-best seller ranking:Gaming Headsets',eVar79: 'product-best seller ranking:Gaming Headsets',}, 'specs bestsellingranking click')" class="link-text">Gaming Headsets</a></td></tr></tbody></table><table class="table-horizontal"><caption>Model</caption><tbody><tr><th>Brand<!-- --> </th><td>Logitech</td></tr><tr><th>Model<!-- --> </th><td>G Pro X</td></tr><tr><th>Part Number<!-- --> </th><td>981-000817</td></tr></tbody></table><table class="table-horizontal"><caption>Details</caption><tbody><tr><th>Color<!-- --> </th><td>Black</td></tr></tbody></table><table class="table-horizontal"><caption>Connectivity</caption><tbody><tr><th>Connection Type<!-- --> </th><td>Wired</td></tr><tr><th>Connector<!-- --> </th><td>USB</td></tr><tr><th>Cord Length<!-- --> </th><td>6.56 Feet PC cable with inline volume and mute<br>4.92 Feet mobile cable with button</td></tr></tbody></table><table class="table-horizontal"><caption>Headphone</caption><tbody><tr><th>Driver Unit<!-- --> </th><td>50mm</td></tr><tr><th>Headphone Frequency Response<!-- --> </th><td>20Hz-20KHz</td></tr><tr><th>Headphone Input Impedance<!-- --> </th><td>35 ohm</td></tr><tr><th>Headphone Sensitivity<!-- --> </th><td>91.7 dB SPL @ 1 mW &amp; 1 cm</td></tr><tr><th>Ear Coupling<!-- --> </th><td>Circumaural</td></tr><tr><th>Weight<!-- --> </th><td>11.28 oz. w/o cable</td></tr></tbody></table><table class="table-horizontal"><caption>Microphone</caption><tbody><tr><th>Microphone Frequency Response<!-- --> </th><td>100Hz-10KHz</td></tr></tbody></table><table class="table-horizontal"><caption>Features</caption><tbody><tr><th>System Requirements<!-- --> </th><td>PC with USB port<br>Windows 7 or later<br>Internet connection for optional software download</td></tr></tbody></table><table class="table-horizontal"><caption>Package Contents</caption><tbody><tr><th>Package Contents<!-- --> </th><td>PRO X gaming headset<br>Memory foam leatherette ear pads<br>Memory foam cloth ear pads<br>USB External sound card<br>Detachable mic<br>2m PC cable with inline volume and mute<br>1.5m mobile cable with button<br>Y splitter for separate mic and headphone ports<br>Carrying bag<br>User documentation</td></tr></tbody></table><table class="table-horizontal"><caption>Additional Information</caption><tbody><tr><th>Date First ...
# Good Quality/Price ratio
# Sturdy</p><p><strong>Cons:</strong> <!-- -->Average sound quality</p><p><strong>Overall Review:</strong> <!-- -->Fast delivery, product is nice and sturdy for the price, audio quality is a bit deceiving, had the G432 previously which cost half the price and the audio quality is very similar if not identical.</p></div><div class="comments-helpful"><div class="button-group"><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-outline"></i><span> 1</span></button><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-broken-outline"></i></button></div></div></div></div></div></div></div><div class="comments-cell has-side-left is-active"><div class="comments-cell-side"><div class="comments-name"><a href="https://www.newegg.ca/d/profile/reviews/OEZxaDFJalk0c0R3Q0RCS25IdE4vM1JZd09zVll5aUQ%3D" class="link-underline" title="View Brandon C.&#x27;s Profile" target="_blank" data-t-events="A" data-t-e-var78="$ - Profile:OEZxaDFJalk0c0R3Q0RCS25IdE4vM1JZd09zVll5aUQ=">Brandon C.</a></div><div class="comments-text">Ownership: 1 week to 1 month</div><div class="comments-text comments-verified-owner"><i class="fa fa-check-circle"></i> Verified Owner</div></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-title"><i class="rating rating-4"></i><span class="comments-title-content">Quality product</span><span class="comments-text">3/12/2021 8:07:00 AM</span></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-content"><p><strong>Pros:</strong> <!-- -->Fits comfortably on my giant head
# Great sound quality - just don&#x27;t install the Logitech drivers/software</p><p><strong>Cons:</strong> <!-- -->Microphone is relatively meh
# Logitech&#x27;s software/drivers are simply awful. Just ignore them</p><p><strong>Overall Review:</strong> <!-- -->I needed a headset that would fit my large head, and with solid construction for lots of on-off throughout the day. So far, very pleased. Nice headset.</p></div><div class="comments-helpful"><div class="button-group"><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-outline"></i><span> 1</span></button><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-broken-outline"></i></button></div></div></div></div></div></div></div><div class="comments-cell has-side-left is-active"><div class="comments-cell-side"><div class="comments-name"><a href="https://www.newegg.ca/d/profile/reviews/WmxxVG0rU0w3QysweHZEVlhHZ1h6ZytwWGhicE9SMXE%3D" class="link-underline" title="View Elian g.&#x27;s Profile" target="_blank" data-t-events="A" data-t-e-var78="$ - Profile:WmxxVG0rU0w3QysweHZEVlhHZ1h6ZytwWGhicE9SMXE=">Elian g.</a></div><div class="comments-text">Ownership: 1 day to 1 week</div><div class="comments-text comments-verified-owner"><i class="fa fa-check-circle"></i> Verified Owner</div></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-title"><i class="rating rating-4"></i><span class="comments-title-content">software issues</span><span class="comments-text">2/5/2020 4:57:24 PM</span></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-content"><p><strong>Cons:</strong> <!-- -->software hasn&#x27;t been working for months</p><p><strong>Overall Review:</strong> <!-- -->software needs serious fixing if u wanna tweak with your mic</p></div><div class="comments-helpful"><div class="button-group"><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-outline"></i><span> 1</span></button><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-broken-outline"></i></button></div></div></div></div></div></div></div><div class="comments-cell has-side-left is-active"><div class="comments-cell-side"><div class="comments-name"><a href="https://www.newegg.ca/d/profile/reviews/UDNEbXBuR2NBL3EybjVCZVhwZVlqOFNKTmZMUllLVnU%3D" class="link-underline" title="View Lonnie H.&#x27;s Profile" target="_blank" data-t-events="A" data-t-e-var78="$ - Profile:UDNEbXBuR2NBL3EybjVCZVhwZVlqOFNKTmZMUllLVnU=">Lonnie H.</a></div><div class="comments-text">Ownership: 1 day to 1 week</div><div class="comments-text comments-verified-owner"><i class="fa fa-check-circle"></i> Verified Owner</div></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-title"><i class="rating rating-5"></i><span class="comments-title-content">Great Product!</span><span class="comments-text">12/23/2019 3:06:18 PM</span></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-content"><p><strong>Pros:</strong> <!-- -->-Very comfortable
# -Sound very clear with no distortion
# -Lightweight
# -Great sounding Microphone
# -The Blue software makes the microphone so much better</p><p><strong>Cons:</strong> <!-- -->-Not much swivel action for the actual ear cups.</p><p><strong>Overall Review:</strong> <!-- -->Highly recommend this headset.</p></div><div class="comments-helpful"><div class="button-group"><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-outline"></i><span> 1</span></button><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-broken-outline"></i></button></div></div></div></div></div></div></div><div class="comments-cell has-side-left is-active"><div class="comments-cell-side"><div class="comments-name"><a href="https://www.newegg.ca/d/profile/reviews/a2N4ZmJKbW15MUFpRUIrVGV0dGgzT2FBZXhzM1g3WFo%3D" class="link-underline" title="View Logan B.&#x27;s Profile" target="_blank" data-t-events="A" data-t-e-var78="$ - Profile:a2N4ZmJKbW15MUFpRUIrVGV0dGgzT2FBZXhzM1g3WFo=">Logan B.</a></div><div class="comments-text">Ownership: 1 week to 1 month</div><div class="comments-text comments-verified-owner"><i class="fa fa-check-circle"></i> Verified Owner</div></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-title"><i class="rating rating-3"></i><span class="comments-title-content">Good, but with some drawbacks.</span><span class="comments-text">3/25/2020 8:24:27 AM</span></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-content"><p><strong>Pros:</strong> <!-- -->Great sound, treble in particular is exceptionally clear.
#
# Mic sounds great.
#
# Great software for tweaking the mic and headphones.</p><p><strong>Cons:</strong> <!-- -->A bit too much clamping force making them uncomfortable for long periods. The drivers hit my ears which becomes very uncomfortable after a couple hours.
#
# Mic is not noise cancelling so you will have to turn gain down to roundabout 20 to stop it from picking up mouse and keyboard presses.
#
# Had to buy aftermarket earpads that i had to force to fit &quot;they dont make them for this headset&quot; to keep my ears from hitting the drivers. So the earpads are too thin.</p><p><strong>Overall Review:</strong> <!-- -->Overall happy with it, but its not nearly as comfortable as my HyperX Cloud 2 set. I bought some aftermarket earpads to stop my ears hitting the drivers, which helps but now im having to kind of work them clamp force so it doesnt squeeze my head so hard.
#
# All in all, they sound great with a great mic. But the HyperX Cloud 2 does have better sound out of the box, and are far more comfortable. If you&#x27;re considering these as opposed to a hyperx headset of some kind, I would say get the hyperx ones for their legendary comfort. Because these ended up costing me around 155 with tax and the earpads. Could have got some Astros for that price.
#
# So this is a decent mid tier headset, with some drawbacks. But you could get better, so i recommend against these.</p></div><div class="comments-helpful"><div class="button-group"><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-outline"></i><span> 9</span></button><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-broken-outline"></i><span> 1</span></button></div></div></div></div></div></div></div><div class="comments-cell has-side-left is-active"><div class="comments-cell-side"><div class="comments-name"><a href="https://www.newegg.ca/d/profile/reviews/aEVoZUVkRVRoa0FpY1BlUTlVWHZaa05yRzlOalFHY2U%3D" class="link-underline" title="View Not Very Happy&#x27;s Profile" target="_blank" data-t-events="A" data-t-e-var78="$ - Profile:aEVoZUVkRVRoa0FpY1BlUTlVWHZaa05yRzlOalFHY2U=">Not Very Happy</a></div><div class="comments-text">Ownership: 1 month to 1 year</div><div class="comments-text comments-verified-owner"><i class="fa fa-check-circle"></i> Verified Owner</div></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-title"><i class="rating rating-1"></i><span class="comments-title-content">Poor build quality</span><span class="comments-text">6/20/2021 11:35:00 AM</span></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-content"><p><strong>Pros:</strong> <!-- -->Sound great, lots of customization features and various attachments for different applications.</p><p><strong>Cons:</strong> <!-- -->Poor build quality in high stress areas. Very brittle plastic covering the adjust mechanism.</p><p><strong>Overall Review:</strong> <!-- -->I have used many different styles of Logitech headphones over the past 30+ years and these are the first to fail as far as build quality.</p><div class="comments-gallery is-auto"><div class="comments-img is-img" data-target="#modal-reviews-gallery-single" data-toggle="modal" data-slider="0"><i class="fa fa-spinner fa-spin"></i></div><div class="comments-img is-img" data-target="#modal-reviews-gallery-single" data-toggle="modal" data-slider="1"><i class="fa fa-spinner fa-spin"></i></div><div class="comments-img is-img" data-target="#modal-reviews-gallery-single" data-toggle="modal" data-slider="2"><i class="fa fa-spinner fa-spin"></i></div></div></div><div class="comments-helpful"><div class="button-group"><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-outline"></i><span> 4</span></button><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-broken-outline"></i><span> 2</span></button></div></div></div></div></div></div></div><div class="comments-cell has-side-left is-active"><div class="comments-cell-side"><div class="comments-name"><a href="https://www.newegg.ca/d/profile/reviews/aVNkdThIUzdEQ3V6K3ZTR2RxTlJQWVZYRjBTWUl5R2M%3D" class="link-underline" title="View Ricky Vargas&#x27;s Profile" target="_blank" data-t-events="A" data-t-e-var78="$ - Profile:aVNkdThIUzdEQ3V6K3ZTR2RxTlJQWVZYRjBTWUl5R2M=">Ricky Vargas</a></div><div class="comments-text">Ownership: 1 week to 1 month</div><div class="comments-text comments-verified-owner"><i class="fa fa-check-circle"></i> Verified Owner</div></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-title"><i class="rating rating-4"></i><span class="comments-title-content">High quality Audio</span><span class="comments-text">9/14/2022 12:39:51 PM</span></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-content"><p><strong>Pros:</strong> <!-- -->-These models are very rigid. They seem well built.
# - the audio is rich and the software package comes with many options I will enjoy using.
# - the fit is snug but not contrictive. Comfy</p><p><strong>Cons:</strong> <!-- -->-The weight may be heavy for some
# - the wires maybe an issue for some</p><p><strong>Overall Review:</strong> <!-- -->I would recommend this as the next step from entry level</p></div><div class="comments-helpful"><div class="button-group"><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-outline"></i></button><button type="button" aria-label="vote" class="btn btn-mini"><i class="fa fa-heart-broken-outline"></i></button></div></div></div></div></div></div></div></div></div></div></div><script type="application/ld+json">{"@context":"http://schema.org/","@type":"Product","aggregateRating":{"@type":"AggregateRating","ratingValue":4,"reviewCount":76},"offers":{"@type":"Offer","availability":"http://schema.org/InStock","price":"119.99","priceCurrency":"CAD","url":"https://www.newegg.ca/black-logitech-g-pro-x/p/N82E16826197345"},"description":"Logitech G Pro X Gaming Headset","name":"Logitech G Pro X Gaming Headset","sku":"N82E16826197345","brand":"Logitech","mpn":"981-000817","gtin12":"097855151032","Model":"981-000817","image":"https://c1.neweggimages.com/ProductImage/26-197-345-V09.jpg","review":[{"@type":"Review","author":"meshari o.","datePublished":"2019-12-15","description":"Pros: the quality of the headset is insane, and the audio is very natural, and the important things make me bought this head set is the mic 😍😍😍😍😍 Cons: the blue voice works in 'PC' only' Overall Review: sorry for my English 🙏","name":"quality & audio","reviewRating":{"@type":"Rating","bestRating":"5","ratingValue":"5","worstRating":"1"}},{"@type":"Review","author":"Anonymous","datePublished":"2022-01-04","description":"Pros: Fast delivery\nGood Quality/Price ratio\nSturdy Cons: Average sound quality Overall Review: Fast delivery, product is nice and sturdy for the price, audio quality is a bit deceiving, had the G432 previously which cost half the price and the audio quality is very similar if not identical.","name":"Just Great","reviewRating":{"@type":"Rating","bestRating":"5","ratingValue":"5","worstRating":"1"}},{"@type":"Review","author":"Brandon C.","datePublished":"2021-03-12","description":"Pros: Fits comfortably on my giant head\nGreat sound quality - just don't install the Logitech drivers/software Cons: Microphone is relatively meh\nLogitech's software/drivers are simply awful. Just ignore them Overall Review: I needed a headset that would fit my large head, and with solid construction for lots of on-off throughout the day. So far, very pleased. Nice headset.","name":"Quality product","reviewRating":{"@type":"Rating","bestRating":"5","ratingValue":"4","worstRating":"1"}},{"@type":"Review","author":"Elian g.","datePublished":"2020-02-05","description":" Cons: software hasn't been working for months Overall Review: software needs serious fixing if u wanna tweak with your mic","name":"software issues","reviewRating":{"@type":"Rating","bestRating":"5","ratingValue":"4","worstRating":"1"}},{"@type":"Review","author":"Lonnie H.","datePublished":"2019-12-23","description":"Pros: -Very comfortable\n-Sound very clear with no distortion\n-Lightweight\n-Great sounding Microphone\n-The Blue software makes the microphone so much better Cons: -Not much swivel action for the actual ear cups. Overall Review: Highly recommend this headset.","name":"Great Product!","reviewRating":{"@type":"Rating","bestRating":"5","ratingValue":"5","worstRating":"1"}},{"@type":"Review","author":"Logan B.","datePublished":"2020-03-25","description":"Pros: Great sound, treble in particular is exceptionally clear.\n\nMic sounds great.\n\nGreat software for tweaking the mic and headphones. Cons: A bit too much clamping force making them uncomfortable for long periods. The drivers hit my ears which becomes very uncomfortable after a couple hours.\n\nMic is not noise cancelling so you will have to turn gain down to roundabout 20 to stop it from picking up mouse and keyboard presses.\n\nHad to buy aftermarket earpads that i had to force to fit \"they dont make them for this headset\" to k ...
#
# 	<li>Return for refund until: January 31, 2023</li>
# 	<li>Return for replacement until: January 31, 2023</li>
# </div><li>This item is covered by Newegg.ca&#x27;s Extended Holiday Return Policy. <a href="https://kb.newegg.ca/Article/Index/12/2?id=1183#10053" class="link-text" target="_blank" title="Return Policy (new window)">Read full return policy for details.</a></li></ul></div></div><div class="info-cell"><div class="info-item"><h4>Manufacturer Contact Info</h4><ul><li><a href="https://www.logitech.com/en-us" target="_blank" class="link-text" title="Manufacturer Product Page (new window)">Manufacturer Product Page</a></li><li><a href="https://www.logitech.com/en-us" target="_blank" class="link-text" title="View Manufacturer Website (new window)">Manufacturer Website</a></li><li>Support Phone: <!-- -->1-646-454-3200</li><li><a href="http://www.logitech.com/index.cfm/support_downloads/&amp;cl=us,en" target="_blank" class="link-text" title="Support Website (new window)">Support Website</a></li><li><a href="https://www.newegg.ca/Logitech/BrandStore/ID-1080" class="link-text">View other products from <!-- -->Logitech</a></li></ul></div></div></div><div><div class="loader"><span class="fa fa-spinner fa-spin"></span>LOADING...</div></div></div><div class="loader"><i class="fa fa-spinner fa-spin"></i>LOADING...</div></div></div></div></div></div></div></div></div><footer id="Page_Footer_Full" class="footer2021 page-section"><div class="page-section bg-lightgrayblue"><div class="page-content-inner"><div class="grid gap-20px col-w-3 col-w-s-1"><div class="grid-col radius-m bg-white col-wide subscribe-box"><form target="newsletterSubscribe" method="post" action="https://secure.newegg.ca/notifications/api/newslettersubscribe?Action=Manage&amp;source=Footer" name="Newsletter"><div class="subscribe-box-inner"><div class="section-title"><div class="section-title-text font-xl no-margin-left">Deals Just For You</div></div><p class="font-l"><strong>Sign up to receive exclusive offers in your inbox.</strong></p><div class="input-group"><div class="input-text has-clear auto-flex"><i class="input-text-icon ico ico-envelope text-gray font-xl" aria-label="email"></i><input type="text" placeholder="Enter your e-mail address" aria-label="Enter your e-mail address" name="LoginName" value="" maxLength="128"/><i class="input-text-clear ico ico-times"><span class="display-none">clear text</span></i></div><button type="button" class="button bg-blue">Sign Up</button></div><p><a class="link-more text-blue" href="https://promotions.newegg.ca/neemail/latest/index-landing.html" title=""><span>View Latest Email Deals</span> <i class="ico ico-angle-right" aria-label="more"></i></a></p><input type="hidden" value="1" name="Subscribe"/></div></form><iframe id="newsletterSubscribe" name="newsletterSubscribe" style="display:none"></iframe><div class="subscribe-box-bg radius-m"><img src="https://c1.neweggimages.com/WebResource/Themes/Nest/bgs/Illus_Subscription@4x.png" alt="subscribe"/></div></div><div class="grid-col radius-m bg-white our-apps"><div class="section-title"><div class="section-title-text font-xl">Download Our APP</div></div><div class="our-apps-combine"><a href="https://k9r54.app.goo.gl/desktoppagefooter" class="our-apps-qrcode" target="_blank"><img src="https://c1.neweggimages.com/WebResource/Themes/Nest/qrcodes/QRCode-APP.png" alt="Shop on Newegg APP"/></a><div class="our-apps-combine-info"><p><strong>Scan the QR code to download App</strong></p><p>Scan this code with your phone&#x27;s camera.</p></div></div><div class="our-apps-bg"><img src="https://c1.neweggimages.com/WebResource/Themes/Nest/bgs/bg_our_app.png" alt="Newegg apps screenshot"/></div></div></div></div></div><nav class="footer2021-sitemap bg-darkblue"><div class="page-content-inner"><div class="grid gap-20px col-w-5 col-w-s-1"><div class="grid-col"><div class="footer2021-sitemap-list "><div class="footer2021-sitemap-title">Customer Service</div><ul><li><a class="font-s" title="Help Center" href="https://kb.newegg.ca">Help Center</a></li><li><a class="font-s" title="Track an Order" href="https:/ ...
# (function (timediff) {
#   window.__SITE__.var8eec7bc4.calcTimediff = function (cont) {
#     if (window.__SITE__.var8eec7bc4.timediff) cont(window.__SITE__.var8eec7bc4.timediff);
#     else if (!isNaN(timediff)) {
#       window.__SITE__.var8eec7bc4.timediff = timediff;
#       cont(timediff);
#     } else {
#       jQuery.get({
#         url: '/d/dynamic-js/product/Product/CAN/initial-json?op=time',
#         cache: false,
#         dataType: 'text',
#         timeout: 60000,
#         success: function(_1, _2, xhr) {
#           var diff = window.__SITE__.var8eec7bc4.timediff = new Date(xhr.getResponseHeader('date')) - Date.now();
#           try { sessionStorage.eggtimediff = diff; } catch(e) {}
#           cont(diff);
#         },
#         error: function () { cont (0); }
#       });
#     }
#   };
# })(parseInt((function(){ try { return sessionStorage.eggtimediff; } catch(e) { return undefined; } })()));
# </script><script defer="">window.__initialState__ = {"Breadcrumbs":[{"Name":"Computer Peripherals","NValue":101702392,"DepaId":-1,"StoreId":380,"StoreType":4,"Tid":1702392,"IsDefault":false},{"Name":"Input Devices","NValue":101702471,"DepaId":-1,"StoreId":29,"StoreType":1,"Tid":1702471,"IsDefault":true},{"Name":"Gaming Headsets","NValue":101702488,"DepaId":-1,"StoreId":3767,"StoreType":2,"Tid":1702488,"IsDefault":false}],"PropertyCollection":{"PropertyGroups":[{"GroupCode":40329,"GroupDescription":"Version","Style":"Swatch","HasPriceAdditionInfo":false,"SelectedProperty":{"Value":1296400,"Description":"G PRO X","DisplayInfo":"G PRO X"},"Properties":[{"Value":1284370,"Description":"G Pro","DisplayInfo":"G Pro"},{"Value":1296400,"Description":"G PRO X","DisplayInfo":"G PRO X"}]}],"AvailableFullPaths":[{"ItemNumber":"26-197-344","UrlKeywords":"black-logitech-g-pro","Path":"1284370"},{"ItemNumber":"26-197-345","UrlKeywords":"black-logitech-g-pro-x","Path":"1296400"}]},"SocialMediaContent":null,"GiftCardStyleList":null,"FlowerSetting":null,"IsShowAutoParts":false,"SponsoredItems":null,"ItemDetail":{"Intelligence":{"Intelligence":null,"TransactionNumber":0,"IntroductionVisible":1,"IntroductionText":"Introduction","IntroductionImage":null,"Introduction":"\u003Cdiv id=\"wc-power-page\"\u003E\u003C\u002Fdiv\u003E\u003Cscript type=\"text\u002Fjavascript\" provider=\"Webcollage\"\u003E(function(){    var loadContent = function () {        window.Webcollage.loadContent(            \"newegg\",            \"9SIANZYBGY3020\",            { reload: true }        );    };    if (window.Webcollage) {        loadContent();    } else {        var script = document.createElement('script');         script.type = 'text\u002Fjavascript';        script.async = true;         script.src = \"https:\u002F\u002Fscontent.webcollage.net\u002Fapi\u002Fv2\u002Fproduct-content\";        if (script.addEventListener) script.addEventListener('load', loadContent);        if (script.attachEvent) script.attachEvent('onload', loadContent);        document.head.appendChild(script);    }}());\u003C\u002Fscript\u003E","IntroductionParagraph1":null,"IntroductionParagraph2":null,"IntroductionParagraph3":null,"HighlightsVisible":0,"HighlightsText":null,"PhotoGalleryVisible":0,"PhotoGalleryText":null,"QuickSpecVisible":0,"QuickSpecText":null,"QuickSpecList":null,"TPCode":null,"HighLightInfoList":null,"ItemIntelligenceList":null,"CategoryIntelligenceInfo":null,"MobileAppFriendly":true},"Warranty":{"WarrantySummary":"We want to ensure your holiday shopping this year is hassle-free. That&rsquo;s why we&rsquo;re automatically extending our return policies on almost every product! For purchases placed between November 1, 2022 and December 25, 2022 you will have until January 31, 2023 to return your product. There&#39;s nothing additional that you have to do!\n\u003Cul\u003E\n\t\u003Cli\u003EReturn for refund until: January 31, 2023\u003C\u002Fli\u003E\n\t\u003Cli\u003EReturn for replacement until: January 31, 2023\u003C\u002Fli\u003E\n\u003C\u002Ful\u003E","WarrantyDayParts":1095,"WarrantyDayLabor":1095,"CustomerServicePhone":"1-646-454-3200","SupportEMail":"","SupportURL":"https:\u002F\u002Fsupport.logi.com\u002Fhc\u002Fen-us\u002F","Is3Party":"0","ServiceProvider":null,"ProviderSupportEmail":null,"ProviderSupportURL":null,"ProviderCustomerServicePhone":null,"Refundable":0,"RMARefundDay":"73","RMAReplacementDay":"73","RestockingFeeRate":0,"WHIWarranty":null,"WarrantyID":10053,"WarrantyName":"Extended Holiday Return Policy"},"Preview":{"TentoeCode":null,"NewTentoeFlag":null,"WebCollageID":null,"IsNewTentoeCode":false,"HasTentoe":false,"HasWebCollage":false,"HasEasy2":false},"DetailSpecification":"\u003CLongDescription Name=\"Detailed Specifications\"\u003E\u003CGroup GroupName=\"\"\u003E\u003CProperty Key=\"Best Seller Ranking\" Value=\"#2 in &lt;a {$BestSellingURL} class=&quot;link-text&quot;&gt;Gaming Headsets&lt;\u002Fa&gt;\" \u002F\u003E\u003C\u002FGroup\u003E\u003CGroup Group ...

# %% [markdown]
# Instead of using `result.text`, we can use Beautiful Soup to parse the html text!

# %%
url = "https://www.newegg.ca/black-logitech-g-pro-x/p/N82E16826197345?Item=N82E16826197345"
result = requests.get(url)
doc = BeautifulSoup(result.text, 'html.parser')
print(doc.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html class="show-tab-store" lang="en-ca"><head><title>Logitech G Pro X Gaming Headset - Newegg.ca</title><meta charset="utf-8"/><meta content="text/html; charset=utf-8" http-equiv="content-type"/><meta content="always" name="referrer"/><meta content="Newegg, Newegg.ca, Logitech G Pro X Gaming Headset" name="keywords"/><meta content="Buy Logitech G Pro X Gaming Headset with fast shipping and top-rated customer service.Once you know, you Newegg!" name="description"/><meta content="https://c1.neweggimages.com/ProductImage/26-197-345-V09.jpg" property="og:image"/><meta content="Buy Logitech G Pro X Gaming Headset with fast shipping and top-rated customer service. Once you know, you Newegg!" property="og:description"/><meta content="Logitech G Pro X Gaming Headset - Newegg.com" property="og:title"/><meta content="https://www.newegg.ca/black-logitech-g-pro-x/p/N82E16826197345" property="og:url"/><meta content="website" property="og:type"/><meta content="english" name="language"/><meta content="© 2000-2022 Newegg Inc." name="copyright"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="index,follow,max-image-preview:large,max-snippet:-1" name="robots"/><meta content="on" name="X-DNS-Prefetch-Control"/><meta content="telephone=no" name="format-detection"/><link href="https://c1.neweggimages.com/WebResource/ngm/newegg.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://www.newegg.ca/black-logitech-g-pro-x/p/N82E16826197345" rel="canonical"/><link href="https://www.newegg.ca/amp/black-logitech-g-pro-x/p/N82E16826197345" rel="amphtml"/><script>window.__PolyfillScripts__={"core-js":"https://c1.neweggimages.com/WebResource/Scripts/WWW/core-js.polyfill.min.js","intersection-observer":"https://c1.neweggimages.com/WebResource/Scripts/WWW/intersection-observer.polyfill.min.js"}</script><script src="https://c1.neweggimages.com/WebResource/Scripts/WWW/runtime~product~ProductDetail-bbb73a14.js"></script><script src="https://c1.neweggimages.com/WebResource/Scripts/WWW/polyfillEntry-0cbc9230.js"></script><link href="https://c1.neweggimages.com/WebResource/Themes/WWW/CSS/vendor~product~ProductDetail-da1cae6dca5b287aef51.css" rel="stylesheet"/><link href="https://c1.neweggimages.com/WebResource/Themes/WWW/CSS/ProductDetail-162534606c4e18ab6e15.css" rel="stylesheet"/><script id="kimoi" type="application/json">[{"type":"setCookie","payload":{"cookie":"CountryRegion","value":"CAN"}},{"type":"setCookie","payload":{"cookie":"LanguageCode","value":"en"}},{"type":"setSubCookie","payload":{"cookie":"CountryConfiguration","subCookieKey":"CurrencyCode","subCookieValue":"CAD"}}]</script></head><body><div><script type="text/javascript">;;;(function(){var e=document.querySelector('meta[name="viewport"]'),t=document.createElement("meta");t.name="viewport",t.content="width=device-width",e||document.head.appendChild(t)})();</script></div><div><script type="text/javascript">var nebs=nebs||{};nebs.errors=[];window.onerror=function(){nebs.errors.push(arguments);return true;}</script></div><div><script src="https://c1.neweggimages.com/webResource/Scripts/WWW/jquery-3.5.1.min.js"></script></div><div><script>!function(){var style = document.createElement('style');style.type = 'text/css';style.innerHTML=document.getElementById('NewTemplate')?'div.grid-col.radius-m.bg-white.our-apps > div.line-horizontal.bg-line.width-auto > span{color:#4D4D4D}.sticky-header-top body{padding-top:115px;height:auto;min-height:calc(100% - 115px);} .sticky-header-top .page-content{padding-top:0;min-height:0;}':'@import url(https://c1.neweggimages.com/webresource/themes/darkmode-min.28.css);.dark-mode #ot-sdk-btn.ot-sdk-show-settings, .dark-mode #ot-sdk-btn.optanon-show-settings{ color: #e3e3e3 !important }.dark-mode #ot-sdk-btn.ot-sdk-show-settings:hover, .dark-mode #ot-sdk-btn.optanon-show-settings:hover{color: #ea9d28 !important;};.footer2021-disclaimer-link:hover {color: #e3e3e3!important;} div.grid-col.radius-m.bg-white.our-apps > div.line-horizontal.bg-lin ...
# <script type="text/javascript">(function(){var darkv = document.cookie.match('(^|;) ?NV_Theme=([^;]*)(;|$)');var dark = darkv ? darkv[2] : "false";if (dark == "true") {if(!document.getElementById('NewTemplate')){jQuery('html').addClass('dark-mode');}else{document.documentElement.classList.add("dark-mode")}}var style = document.createElement("style");var darkCss='#Dark_Mode{display:none;}.header2021-toggle{z-index:5}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:20px}.header2021-toggle:hover{transform:scale(1)}.header2021-toggle:hover .bg-lightgray{background-color:rgba(235,235,235,1)}.header2021-toggle .toggle-body{border:1px solid #212121;border-radius:30px}.header2021-toggle .toggle-body-inner:after{border-radius:30px;width:30px;top:0;bottom:0;margin-left:-1px;box-shadow:0 1px 6px 0 rgb(0 0 0 / 16%)}.header2021-toggle .toggle-handle{font-size:20px;color:#474747}.header2021-toggle .dark-mode-tooltip{padding:5px 15px;white-space:nowrap}.header2021-toggle.menu.at-bottom .menu-body{left:auto;right:0;margin-top:12px;text-align:left}.header2021-toggle.at-bottom>.menu-arrow{left:auto;right:20px;text-align:left}.header2021-toggle.at-bottom>.menu-body>.menu-arrow{left:auto!important;right:20px}.dark-mode .header2021-toggle .toggle-handle.take-on{padding-left:8px}.dark-mode .header2021-toggle:hover .bg-lightgray{background-color:#ea7421}.dark-mode .header2021-toggle .toggle-body{border:1px solid #835b38}.dark-mode .header2021-toggle .bg-lightgray{background-color:#e05d00}.dark-mode .header2021-toggle input[type="checkbox"]:checked ~ .toggle-body .toggle-body-inner:after{margin-right:0;margin-left:0;top:0}.dark-mode .header2021-toggle .toggle-body-inner:after{box-shadow:0 6px 6px 0 rgb(0 0 0 / 16%)}@media(max-width:599px){.header2021-inner{padding:15px 2px}.header2021-logo{width:60px}.header2021-country.header2021-nav:not(:first-child){margin-left:15px}.header2021-toggle .bg-lightgray{background:#fff}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:15px}.header2021-toggle .toggle-body{min-width:30px;height:30px;border-radius:50%}.header2021-toggle .toggle-body-inner{width:100%;height:100%;transform:translateX(0);justify-content:center;align-items:center}.header2021-toggle .toggle-handle{height:100%;line-height:1.1;padding:0;font-size:22px;justify-content:center;z-index:2}.header2021-toggle .toggle-body-inner:after{content:none}.header2021-toggle .toggle-handle.take-off{padding:0}.header2021-toggle .toggle-handle.take-on,.header2021-toggle.menu.at-bottom .menu-body{display:none}.dark-mode .header2021-toggle .toggle-handle.take-on{display:flex;padding:0}.dark-mode .header2021-toggle .toggle-handle.take-off{display:none}.section-right>.line-vertical-new{margin:0 0 0 10px}}@media(max-width:350px){.header2021-nav-inner,.header2021-nav.menu .header2021-nav-inner{padding-left:26px;height:26px;min-height:26px}.header2021-country-flag{width:26px;height:26px}.header2021-nav-icon{width:26px;height:26px;line-height:26px;font-size:24px;top:2px}.header2021-nav ~ .header2021-nav{margin-left:5px}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:10px}.header2021-toggle .toggle-body{min-width:24px;height:24px}.header2021-toggle .toggle-handle{font-size:16px}}';try{style.appendChild(document.createTextNode(darkCss));}catch(ex){style.styleSheet.cssText = darkCss;}var head = document.getElementsByTagName("head")[0];head&&head.appendChild(style);var darkbut = jQuery('<div class="header2021-nav header2021-toggle toggle toggle-m menu at-bottom"><label id="darkLabel"><input type="checkbox" id="checkdarkmode"><span class="toggle-body bg-lightgray font-l"><span class="toggle-body-inner"><span class="toggle-handle take-on">&#9790;</span><span class="toggle-handle take-off ">&#9728;</span></span></span></label><div id="darkModal" class="menu-body bg-white radius-s shadow-level-1"><i class="menu-arrow"></i><p class="dark-mode-tooltip">Switch to Dark Mode</p></div></div>');jQuery(document).ready(function (){jQuery('.head ...
# </div><div><script type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-W26F4QT');</script></div><div><style>@import url(https://c1.neweggimages.com/webresource/themes/WWW/CSS/fixManufactory.css)</style></div><div> <script defer="" src="https://c1.neweggimages.com/webresource/Scripts/Others/TopRatedSeller/new-feature-script.2.0.5.min.js" type="text/javascript"></script></div><div>
# <script type="text/javascript">
#             ;;;(function() {
#                 window.__ga_forbiddenList = null;
#                 window.__ga_mappingAdobe = [{
#                     events:["event63"],
#                     eventName:"click_event",
#                     mapping:{
#                         links:"evar78"
#                     }
#                 }];
#                 window.__ga_linkInternalFilters = "javascript:,newegg.com,gamecrate.com,abs.com,checkout.us.zip.co,zip.co,checkout.quadpay.com,3debspay.boc.cn,alfabank.ru,arcot.com,billmelater.com,citibank.co.kr,ftpsllc.com,garanti.com.tr,hyundaicard.com,kbcard.com,keb.co.kr,masterpass.com,mycardsecure.com,newegg3.com.sh,paypal.com,samsungcard.co.kr,secure2gw.ro,securecode.com,secureserver.net,securesuite.co.uk,securesuite.net,shinhancard.com,verifiedbyvisa.com,visa.com,visa.com.ar,web.v.me,secondfunnel.com,cardinalcommerce.com,secure.neweggbusiness.com,www-newegg-com.cdn.ampproject.org,www.newegg.ca,secure.newegg.ca,kb.neweggbusiness.com,www.neweggbusiness.com,help.newegg.ca,secure.m.newegg.ca,secure.newegg.com,www.rosewill.com,neweggbusiness.com,sellerportal.newegg.cn,partner.gqc.newegg.space,help.neweggbusiness.com,secure.newegg6.com.sh,sellerportal62780.gqc.newegg.space,central3.newegg.org,partner.newegg.cn,secure.newegg4.com.sh,newegg.io,newegggpu.com,justgpu.com";
#             })()
#         </script>
# </div><div id="app"><header class="header2021 bg-white"><div class="page-content-inner"><div class="header2021-inner"><div class="section-left auto-flex"><div><div class="header2021-hamburger-new header2021-hamburger menu at-bottom"><i aria-label="Site Menu" class="header2021-hamburger-icon ico ico-bars bg-transparent-gray"></i></div></div><div class="header2021-logo"><a class="header2021-logo-img" href="https://www.newegg.ca/" title="Newegg.ca - Computer Parts, Laptops, Electronics, HDTVs, Digital Cameras and More!"><img alt="Newegg" src="https://c1.neweggimages.com/WebResource/Themes/Nest/logos/Newegg_full_color_logo_RGB.SVG"/></a></div><div class="header2021-nav header2021-location menu at-bottom"><a class="header2021-nav-inner bg-transparent-gray" href="#" title="Select address "><i aria-label="icon of my location" class="ico ico-map-marker header2021-nav-icon"></i><div class="header2021-nav-title text-gray font-s">Hello<!-- --> <span class="header2021-info-nowrap header2021-info-min"></span></div><div class="header2021-nav-subtitle"><span class="">Select address</span> <span></span></div></a></div><div class="header2021-search auto-flex"><div class="header2021-search-inner"><div class="header2021-search-box auto-flex"><input autocomplete="off" title="Search Site" type="search" value=""/></div><div class="header2021-search-button"><button class="ico ico-search"><span class="display-none">Search</span></button></div></div></div></div><div class="section-right"><div class="header2021-nav header2021-country menu at-bottom"><a class="header2021-country-flag bg-transparent-gray" title="Change Country"><i class="flag ca"></i><span class="display-none">Change Country</span></a></div><div class="nav-complex"><a class="header2021-nav-inner bg-transparent-gray" href="https://secure.newegg.ca/login/signin?nextpage=" title="My Account"><i aria-label="icon of my account" class="ico ico-user header2021-nav-icon"></i></a></div><div class="header2021-nav header2021-returns s-hide"><a class="header2021-nav-inner bg-transparent-gray" href="https://secure.newegg.ca/orders/list" title="Orders"><div class="header2021-nav-title text-gray font-s"><span>Returns</span></div><div class="header2021-nav-subtitle">&amp; Orders</div></a></div><div class="header2021-nav header2021-cart"><a aria-label="Shopping Cart" class="header2021-nav-inner bg-transparent-gray" href="https://secure.newegg.ca/shop/cart" title="Shopping Cart"><i aria-label="icon of shopping cart" class="ico ico-shopping-cart header2021-nav-icon"></i></a></div></div></div><div class="header2021-inner"><div class="section-left auto-flex"><div class="header2021-portals" id="Portals_swiper"><div class="swiper-container swiper-container-horizontal"><div class="swiper-wrapper"><div class="swiper-slide"></div><div class="swiper-slide"><a "="" class="header2021-portal" href="////www.newegg.ca/promotions/nepro/22-1968/index.html?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Black+Friday+Ads&amp;icid=733797" id="trendingBanner_733797" title="Black Friday Ads"><span class="font-s">Black Friday Ads</span></a></div><div class="swiper-slide"><a "="" class="header2021-portal" href="////www.newegg.ca/Spotlight/Store/ID-14?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Spotlight&amp;icid=726849" id="trendingBanner_726849" title="Spotlight"><span class="font-s">Spotlight</span></a></div><div class="swiper-slide"><a "="" class="header2021-portal" href="////www.newegg.ca/d/best-sellers?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Best+Sellers&amp;icid=623097" id="trendingBanner_623097" title="Best Sellers"><span class="font-s">Best Sellers</span></a></div><div class="swiper-slide"><a "="" class="header2021-portal" href="////www.newegg.ca/Elite-Deals/EventSaleStore/ID-779?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Elite+Deals&amp;icid=649302" id="trendingBanner_649302" title="Elite Deals"><span class="font-s">Elite Deals</span></a></div><div class="swiper-slide"><a "="" class="header2021-portal" href="////www.neweg ...
# <span class="font-s">
#                                 Browsing History
#                                 </span>
# <i aria-label="dropdown" class="ico ico-angle-down"></i>
# <div class="menu-arrow"></div>
# </li><li>Detachable 6mm Mic+ - Large mic for amazingly clear voice comms</li></ul></div><div class="product-msg-group"></div></div></div><div class="product-contents"><div class="page-section"><div class="page-section-inner"><div id="PDP_product-recommend"></div><div class="tab-box" id="product-details"><div class="tab-navs"><div class="tab-nav active">Overview</div><div class="tab-nav">Specs</div><div class="tab-nav">Reviews</div></div><div class="tab-panes"><div class="tab-pane" style="display:block"><div class="article" id="product-overview"><div><div id="wc-power-page"></div><script provider="Webcollage" type="text/javascript">(function(){    var loadContent = function () {        window.Webcollage.loadContent(            "newegg",            "9SIANZYBGY3020",            { reload: true }        );    };    if (window.Webcollage) {        loadContent();    } else {        var script = document.createElement('script');         script.type = 'text/javascript';        script.async = true;         script.src = "https://scontent.webcollage.net/api/v2/product-content";        if (script.addEventListener) script.addEventListener('load', loadContent);        if (script.attachEvent) script.attachEvent('onload', loadContent);        document.head.appendChild(script);    }}());</script></div></div></div><div class="tab-pane" style="display:none"><h2 class="swiper-box-top-title margin-bottom">Learn more about the <!-- -->Logitech G Pro X</h2><table class="table-horizontal"><caption></caption><tbody><tr><th>Best Seller Ranking<!-- --> </th><td>#2 in <a class="link-text" href="https://www.newegg.ca/d/Best-Sellers/Gaming-Headsets/s/ID-3767" onclick="Biz.Common.SiteCatalyst.sendForOnClick({events: 'event63',eVar78: 'product-best seller ranking:Gaming Headsets',eVar79: 'product-best seller ranking:Gaming Headsets',}, 'specs bestsellingranking click')">Gaming Headsets</a></td></tr></tbody></table><table class="table-horizontal"><caption>Model</caption><tbody><tr><th>Brand<!-- --> </th><td>Logitech</td></tr><tr><th>Model<!-- --> </th><td>G Pro X</td></tr><tr><th>Part Number<!-- --> </th><td>981-000817</td></tr></tbody></table><table class="table-horizontal"><caption>Details</caption><tbody><tr><th>Color<!-- --> </th><td>Black</td></tr></tbody></table><table class="table-horizontal"><caption>Connectivity</caption><tbody><tr><th>Connection Type<!-- --> </th><td>Wired</td></tr><tr><th>Connector<!-- --> </th><td>USB</td></tr><tr><th>Cord Length<!-- --> </th><td>6.56 Feet PC cable with inline volume and mute<br/>4.92 Feet mobile cable with button</td></tr></tbody></table><table class="table-horizontal"><caption>Headphone</caption><tbody><tr><th>Driver Unit<!-- --> </th><td>50mm</td></tr><tr><th>Headphone Frequency Response<!-- --> </th><td>20Hz-20KHz</td></tr><tr><th>Headphone Input Impedance<!-- --> </th><td>35 ohm</td></tr><tr><th>Headphone Sensitivity<!-- --> </th><td>91.7 dB SPL @ 1 mW &amp; 1 cm</td></tr><tr><th>Ear Coupling<!-- --> </th><td>Circumaural</td></tr><tr><th>Weight<!-- --> </th><td>11.28 oz. w/o cable</td></tr></tbody></table><table class="table-horizontal"><caption>Microphone</caption><tbody><tr><th>Microphone Frequency Response<!-- --> </th><td>100Hz-10KHz</td></tr></tbody></table><table class="table-horizontal"><caption>Features</caption><tbody><tr><th>System Requirements<!-- --> </th><td>PC with USB port<br/>Windows 7 or later<br/>Internet connection for optional software download</td></tr></tbody></table><table class="table-horizontal"><caption>Package Contents</caption><tbody><tr><th>Package Contents<!-- --> </th><td>PRO X gaming headset<br/>Memory foam leatherette ear pads<br/>Memory foam cloth ear pads<br/>USB External sound card<br/>Detachable mic<br/>2m PC cable with inline volume and mute<br/>1.5m mobile cable with button<br/>Y splitter for separate mic and headphone ports<br/>Carrying bag<br/>User documentation</td></tr></tbody></table><table class="table-horizontal"><caption>Additional Information</caption><tbody><tr> ...
# Good Quality/Price ratio
# Sturdy</p><p><strong>Cons:</strong> <!-- -->Average sound quality</p><p><strong>Overall Review:</strong> <!-- -->Fast delivery, product is nice and sturdy for the price, audio quality is a bit deceiving, had the G432 previously which cost half the price and the audio quality is very similar if not identical.</p></div><div class="comments-helpful"><div class="button-group"><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-outline"></i><span> 1</span></button><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-broken-outline"></i></button></div></div></div></div></div></div></div><div class="comments-cell has-side-left is-active"><div class="comments-cell-side"><div class="comments-name"><a class="link-underline" data-t-e-var78="$ - Profile:OEZxaDFJalk0c0R3Q0RCS25IdE4vM1JZd09zVll5aUQ=" data-t-events="A" href="https://www.newegg.ca/d/profile/reviews/OEZxaDFJalk0c0R3Q0RCS25IdE4vM1JZd09zVll5aUQ%3D" target="_blank" title="View Brandon C.'s Profile">Brandon C.</a></div><div class="comments-text">Ownership: 1 week to 1 month</div><div class="comments-text comments-verified-owner"><i class="fa fa-check-circle"></i> Verified Owner</div></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-title"><i class="rating rating-4"></i><span class="comments-title-content">Quality product</span><span class="comments-text">3/12/2021 8:07:00 AM</span></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-content"><p><strong>Pros:</strong> <!-- -->Fits comfortably on my giant head
# Great sound quality - just don't install the Logitech drivers/software</p><p><strong>Cons:</strong> <!-- -->Microphone is relatively meh
# Logitech's software/drivers are simply awful. Just ignore them</p><p><strong>Overall Review:</strong> <!-- -->I needed a headset that would fit my large head, and with solid construction for lots of on-off throughout the day. So far, very pleased. Nice headset.</p></div><div class="comments-helpful"><div class="button-group"><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-outline"></i><span> 1</span></button><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-broken-outline"></i></button></div></div></div></div></div></div></div><div class="comments-cell has-side-left is-active"><div class="comments-cell-side"><div class="comments-name"><a class="link-underline" data-t-e-var78="$ - Profile:WmxxVG0rU0w3QysweHZEVlhHZ1h6ZytwWGhicE9SMXE=" data-t-events="A" href="https://www.newegg.ca/d/profile/reviews/WmxxVG0rU0w3QysweHZEVlhHZ1h6ZytwWGhicE9SMXE%3D" target="_blank" title="View Elian g.'s Profile">Elian g.</a></div><div class="comments-text">Ownership: 1 day to 1 week</div><div class="comments-text comments-verified-owner"><i class="fa fa-check-circle"></i> Verified Owner</div></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-title"><i class="rating rating-4"></i><span class="comments-title-content">software issues</span><span class="comments-text">2/5/2020 4:57:24 PM</span></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-content"><p><strong>Cons:</strong> <!-- -->software hasn't been working for months</p><p><strong>Overall Review:</strong> <!-- -->software needs serious fixing if u wanna tweak with your mic</p></div><div class="comments-helpful"><div class="button-group"><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-outline"></i><span> 1</span></button><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-broken-outline"></i></button></div></div></div></div></div></div></div><div class="comments-cell has-side-left is-active"><div class="comments-cell-side"><div class="comments-name"><a class="link-underline" data-t-e-var78="$ - Profile:UDNEbXBuR2NBL3EybjVCZVhwZVlqOFNKTmZMUllLVnU=" data-t-events="A" href="https://www.newegg.ca/d/profile/reviews/UDNEbXBuR2NBL3EybjVCZVhwZVlqOFNKTmZMUllLVnU%3D" target="_blank" title="View Lonnie H.'s Profile">Lonnie H.</a></div><div class="comments-text">Ownership: 1 day to 1 week</div><div class="comments-text comments-verified-owner"><i class="fa fa-check-circle"></i> Verified Owner</div></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-title"><i class="rating rating-5"></i><span class="comments-title-content">Great Product!</span><span class="comments-text">12/23/2019 3:06:18 PM</span></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-content"><p><strong>Pros:</strong> <!-- -->-Very comfortable
# -Sound very clear with no distortion
# -Lightweight
# -Great sounding Microphone
# -The Blue software makes the microphone so much better</p><p><strong>Cons:</strong> <!-- -->-Not much swivel action for the actual ear cups.</p><p><strong>Overall Review:</strong> <!-- -->Highly recommend this headset.</p></div><div class="comments-helpful"><div class="button-group"><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-outline"></i><span> 1</span></button><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-broken-outline"></i></button></div></div></div></div></div></div></div><div class="comments-cell has-side-left is-active"><div class="comments-cell-side"><div class="comments-name"><a class="link-underline" data-t-e-var78="$ - Profile:a2N4ZmJKbW15MUFpRUIrVGV0dGgzT2FBZXhzM1g3WFo=" data-t-events="A" href="https://www.newegg.ca/d/profile/reviews/a2N4ZmJKbW15MUFpRUIrVGV0dGgzT2FBZXhzM1g3WFo%3D" target="_blank" title="View Logan B.'s Profile">Logan B.</a></div><div class="comments-text">Ownership: 1 week to 1 month</div><div class="comments-text comments-verified-owner"><i class="fa fa-check-circle"></i> Verified Owner</div></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-title"><i class="rating rating-3"></i><span class="comments-title-content">Good, but with some drawbacks.</span><span class="comments-text">3/25/2020 8:24:27 AM</span></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-content"><p><strong>Pros:</strong> <!-- -->Great sound, treble in particular is exceptionally clear.
#
# Mic sounds great.
#
# Great software for tweaking the mic and headphones.</p><p><strong>Cons:</strong> <!-- -->A bit too much clamping force making them uncomfortable for long periods. The drivers hit my ears which becomes very uncomfortable after a couple hours.
#
# Mic is not noise cancelling so you will have to turn gain down to roundabout 20 to stop it from picking up mouse and keyboard presses.
#
# Had to buy aftermarket earpads that i had to force to fit "they dont make them for this headset" to keep my ears from hitting the drivers. So the earpads are too thin.</p><p><strong>Overall Review:</strong> <!-- -->Overall happy with it, but its not nearly as comfortable as my HyperX Cloud 2 set. I bought some aftermarket earpads to stop my ears hitting the drivers, which helps but now im having to kind of work them clamp force so it doesnt squeeze my head so hard.
#
# All in all, they sound great with a great mic. But the HyperX Cloud 2 does have better sound out of the box, and are far more comfortable. If you're considering these as opposed to a hyperx headset of some kind, I would say get the hyperx ones for their legendary comfort. Because these ended up costing me around 155 with tax and the earpads. Could have got some Astros for that price.
#
# So this is a decent mid tier headset, with some drawbacks. But you could get better, so i recommend against these.</p></div><div class="comments-helpful"><div class="button-group"><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-outline"></i><span> 9</span></button><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-broken-outline"></i><span> 1</span></button></div></div></div></div></div></div></div><div class="comments-cell has-side-left is-active"><div class="comments-cell-side"><div class="comments-name"><a class="link-underline" data-t-e-var78="$ - Profile:aEVoZUVkRVRoa0FpY1BlUTlVWHZaa05yRzlOalFHY2U=" data-t-events="A" href="https://www.newegg.ca/d/profile/reviews/aEVoZUVkRVRoa0FpY1BlUTlVWHZaa05yRzlOalFHY2U%3D" target="_blank" title="View Not Very Happy's Profile">Not Very Happy</a></div><div class="comments-text">Ownership: 1 month to 1 year</div><div class="comments-text comments-verified-owner"><i class="fa fa-check-circle"></i> Verified Owner</div></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-title"><i class="rating rating-1"></i><span class="comments-title-content">Poor build quality</span><span class="comments-text">6/20/2021 11:35:00 AM</span></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-content"><p><strong>Pros:</strong> <!-- -->Sound great, lots of customization features and various attachments for different applications.</p><p><strong>Cons:</strong> <!-- -->Poor build quality in high stress areas. Very brittle plastic covering the adjust mechanism.</p><p><strong>Overall Review:</strong> <!-- -->I have used many different styles of Logitech headphones over the past 30+ years and these are the first to fail as far as build quality.</p><div class="comments-gallery is-auto"><div class="comments-img is-img" data-slider="0" data-target="#modal-reviews-gallery-single" data-toggle="modal"><i class="fa fa-spinner fa-spin"></i></div><div class="comments-img is-img" data-slider="1" data-target="#modal-reviews-gallery-single" data-toggle="modal"><i class="fa fa-spinner fa-spin"></i></div><div class="comments-img is-img" data-slider="2" data-target="#modal-reviews-gallery-single" data-toggle="modal"><i class="fa fa-spinner fa-spin"></i></div></div></div><div class="comments-helpful"><div class="button-group"><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-outline"></i><span> 4</span></button><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-broken-outline"></i><span> 2</span></button></div></div></div></div></div></div></div><div class="comments-cell has-side-left is-active"><div class="comments-cell-side"><div class="comments-name"><a class="link-underline" data-t-e-var78="$ - Profile:aVNkdThIUzdEQ3V6K3ZTR2RxTlJQWVZYRjBTWUl5R2M=" data-t-events="A" href="https://www.newegg.ca/d/profile/reviews/aVNkdThIUzdEQ3V6K3ZTR2RxTlJQWVZYRjBTWUl5R2M%3D" target="_blank" title="View Ricky Vargas's Profile">Ricky Vargas</a></div><div class="comments-text">Ownership: 1 week to 1 month</div><div class="comments-text comments-verified-owner"><i class="fa fa-check-circle"></i> Verified Owner</div></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-title"><i class="rating rating-4"></i><span class="comments-title-content">High quality Audio</span><span class="comments-text">9/14/2022 12:39:51 PM</span></div><div class="comments-cell-body"><div class="comments-cell-body-inner"><div class="comments-content"><p><strong>Pros:</strong> <!-- -->-These models are very rigid. They seem well built.
# - the audio is rich and the software package comes with many options I will enjoy using.
# - the fit is snug but not contrictive. Comfy</p><p><strong>Cons:</strong> <!-- -->-The weight may be heavy for some
# - the wires maybe an issue for some</p><p><strong>Overall Review:</strong> <!-- -->I would recommend this as the next step from entry level</p></div><div class="comments-helpful"><div class="button-group"><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-outline"></i></button><button aria-label="vote" class="btn btn-mini" type="button"><i class="fa fa-heart-broken-outline"></i></button></div></div></div></div></div></div></div></div></div></div></div><script type="application/ld+json">{"@context":"http://schema.org/","@type":"Product","aggregateRating":{"@type":"AggregateRating","ratingValue":4,"reviewCount":76},"offers":{"@type":"Offer","availability":"http://schema.org/InStock","price":"119.99","priceCurrency":"CAD","url":"https://www.newegg.ca/black-logitech-g-pro-x/p/N82E16826197345"},"description":"Logitech G Pro X Gaming Headset","name":"Logitech G Pro X Gaming Headset","sku":"N82E16826197345","brand":"Logitech","mpn":"981-000817","gtin12":"097855151032","Model":"981-000817","image":"https://c1.neweggimages.com/ProductImage/26-197-345-V09.jpg","review":[{"@type":"Review","author":"meshari o.","datePublished":"2019-12-15","description":"Pros: the quality of the headset is insane, and the audio is very natural, and the important things make me bought this head set is the mic 😍😍😍😍😍 Cons: the blue voice works in 'PC' only' Overall Review: sorry for my English 🙏","name":"quality & audio","reviewRating":{"@type":"Rating","bestRating":"5","ratingValue":"5","worstRating":"1"}},{"@type":"Review","author":"Anonymous","datePublished":"2022-01-04","description":"Pros: Fast delivery\nGood Quality/Price ratio\nSturdy Cons: Average sound quality Overall Review: Fast delivery, product is nice and sturdy for the price, audio quality is a bit deceiving, had the G432 previously which cost half the price and the audio quality is very similar if not identical.","name":"Just Great","reviewRating":{"@type":"Rating","bestRating":"5","ratingValue":"5","worstRating":"1"}},{"@type":"Review","author":"Brandon C.","datePublished":"2021-03-12","description":"Pros: Fits comfortably on my giant head\nGreat sound quality - just don't install the Logitech drivers/software Cons: Microphone is relatively meh\nLogitech's software/drivers are simply awful. Just ignore them Overall Review: I needed a headset that would fit my large head, and with solid construction for lots of on-off throughout the day. So far, very pleased. Nice headset.","name":"Quality product","reviewRating":{"@type":"Rating","bestRating":"5","ratingValue":"4","worstRating":"1"}},{"@type":"Review","author":"Elian g.","datePublished":"2020-02-05","description":" Cons: software hasn't been working for months Overall Review: software needs serious fixing if u wanna tweak with your mic","name":"software issues","reviewRating":{"@type":"Rating","bestRating":"5","ratingValue":"4","worstRating":"1"}},{"@type":"Review","author":"Lonnie H.","datePublished":"2019-12-23","description":"Pros: -Very comfortable\n-Sound very clear with no distortion\n-Lightweight\n-Great sounding Microphone\n-The Blue software makes the microphone so much better Cons: -Not much swivel action for the actual ear cups. Overall Review: Highly recommend this headset.","name":"Great Product!","reviewRating":{"@type":"Rating","bestRating":"5","ratingValue":"5","worstRating":"1"}},{"@type":"Review","author":"Logan B.","datePublished":"2020-03-25","description":"Pros: Great sound, treble in particular is exceptionally clear.\n\nMic sounds great.\n\nGreat software for tweaking the mic and headphones. Cons: A bit too much clamping force making them uncomfortable for long periods. The drivers hit my ears which becomes very uncomfortable after a couple hours.\n\nMic is not noise cancelling so you will have to turn gain down to roundabout 20 to stop it from picking up mouse and keyboard presses.\n\nHad to buy aftermarket earpads that i had to force to fit \"they dont make them for this headset\" to k ...
#
# 	<li>Return for refund until: January 31, 2023</li>
# <li>Return for replacement until: January 31, 2023</li>
# </div><li>This item is covered by Newegg.ca's Extended Holiday Return Policy. <a class="link-text" href="https://kb.newegg.ca/Article/Index/12/2?id=1183#10053" target="_blank" title="Return Policy (new window)">Read full return policy for details.</a></li></ul></div></div><div class="info-cell"><div class="info-item"><h4>Manufacturer Contact Info</h4><ul><li><a class="link-text" href="https://www.logitech.com/en-us" target="_blank" title="Manufacturer Product Page (new window)">Manufacturer Product Page</a></li><li><a class="link-text" href="https://www.logitech.com/en-us" target="_blank" title="View Manufacturer Website (new window)">Manufacturer Website</a></li><li>Support Phone: <!-- -->1-646-454-3200</li><li><a class="link-text" href="http://www.logitech.com/index.cfm/support_downloads/&amp;cl=us,en" target="_blank" title="Support Website (new window)">Support Website</a></li><li><a class="link-text" href="https://www.newegg.ca/Logitech/BrandStore/ID-1080">View other products from <!-- -->Logitech</a></li></ul></div></div></div><div><div class="loader"><span class="fa fa-spinner fa-spin"></span>LOADING...</div></div></div><div class="loader"><i class="fa fa-spinner fa-spin"></i>LOADING...</div></div></div></div></div></div></div></div></div><footer class="footer2021 page-section" id="Page_Footer_Full"><div class="page-section bg-lightgrayblue"><div class="page-content-inner"><div class="grid gap-20px col-w-3 col-w-s-1"><div class="grid-col radius-m bg-white col-wide subscribe-box"><form action="https://secure.newegg.ca/notifications/api/newslettersubscribe?Action=Manage&amp;source=Footer" method="post" name="Newsletter" target="newsletterSubscribe"><div class="subscribe-box-inner"><div class="section-title"><div class="section-title-text font-xl no-margin-left">Deals Just For You</div></div><p class="font-l"><strong>Sign up to receive exclusive offers in your inbox.</strong></p><div class="input-group"><div class="input-text has-clear auto-flex"><i aria-label="email" class="input-text-icon ico ico-envelope text-gray font-xl"></i><input aria-label="Enter your e-mail address" maxlength="128" name="LoginName" placeholder="Enter your e-mail address" type="text" value=""/><i class="input-text-clear ico ico-times"><span class="display-none">clear text</span></i></div><button class="button bg-blue" type="button">Sign Up</button></div><p><a class="link-more text-blue" href="https://promotions.newegg.ca/neemail/latest/index-landing.html" title=""><span>View Latest Email Deals</span> <i aria-label="more" class="ico ico-angle-right"></i></a></p><input name="Subscribe" type="hidden" value="1"/></div></form><iframe id="newsletterSubscribe" name="newsletterSubscribe" style="display:none"></iframe><div class="subscribe-box-bg radius-m"><img alt="subscribe" src="https://c1.neweggimages.com/WebResource/Themes/Nest/bgs/Illus_Subscription@4x.png"/></div></div><div class="grid-col radius-m bg-white our-apps"><div class="section-title"><div class="section-title-text font-xl">Download Our APP</div></div><div class="our-apps-combine"><a class="our-apps-qrcode" href="https://k9r54.app.goo.gl/desktoppagefooter" target="_blank"><img alt="Shop on Newegg APP" src="https://c1.neweggimages.com/WebResource/Themes/Nest/qrcodes/QRCode-APP.png"/></a><div class="our-apps-combine-info"><p><strong>Scan the QR code to download App</strong></p><p>Scan this code with your phone's camera.</p></div></div><div class="our-apps-bg"><img alt="Newegg apps screenshot" src="https://c1.neweggimages.com/WebResource/Themes/Nest/bgs/bg_our_app.png"/></div></div></div></div></div><nav class="footer2021-sitemap bg-darkblue"><div class="page-content-inner"><div class="grid gap-20px col-w-5 col-w-s-1"><div class="grid-col"><div class="footer2021-sitemap-list"><div class="footer2021-sitemap-title">Customer Service</div><ul><li><a class="font-s" href="https://kb.newegg.ca" title="Help Center">Help Center</a></li><li><a class="font-s" href="https://secure.newegg.ca/orders/find?Sour ...
# (function (timediff) {
#   window.__SITE__.var8eec7bc4.calcTimediff = function (cont) {
#     if (window.__SITE__.var8eec7bc4.timediff) cont(window.__SITE__.var8eec7bc4.timediff);
#     else if (!isNaN(timediff)) {
#       window.__SITE__.var8eec7bc4.timediff = timediff;
#       cont(timediff);
#     } else {
#       jQuery.get({
#         url: '/d/dynamic-js/product/Product/CAN/initial-json?op=time',
#         cache: false,
#         dataType: 'text',
#         timeout: 60000,
#         success: function(_1, _2, xhr) {
#           var diff = window.__SITE__.var8eec7bc4.timediff = new Date(xhr.getResponseHeader('date')) - Date.now();
#           try { sessionStorage.eggtimediff = diff; } catch(e) {}
#           cont(diff);
#         },
#         error: function () { cont (0); }
#       });
#     }
#   };
# })(parseInt((function(){ try { return sessionStorage.eggtimediff; } catch(e) { return undefined; } })()));
# </script><script defer="">window.__initialState__ = {"Breadcrumbs":[{"Name":"Computer Peripherals","NValue":101702392,"DepaId":-1,"StoreId":380,"StoreType":4,"Tid":1702392,"IsDefault":false},{"Name":"Input Devices","NValue":101702471,"DepaId":-1,"StoreId":29,"StoreType":1,"Tid":1702471,"IsDefault":true},{"Name":"Gaming Headsets","NValue":101702488,"DepaId":-1,"StoreId":3767,"StoreType":2,"Tid":1702488,"IsDefault":false}],"PropertyCollection":{"PropertyGroups":[{"GroupCode":40329,"GroupDescription":"Version","Style":"Swatch","HasPriceAdditionInfo":false,"SelectedProperty":{"Value":1296400,"Description":"G PRO X","DisplayInfo":"G PRO X"},"Properties":[{"Value":1284370,"Description":"G Pro","DisplayInfo":"G Pro"},{"Value":1296400,"Description":"G PRO X","DisplayInfo":"G PRO X"}]}],"AvailableFullPaths":[{"ItemNumber":"26-197-344","UrlKeywords":"black-logitech-g-pro","Path":"1284370"},{"ItemNumber":"26-197-345","UrlKeywords":"black-logitech-g-pro-x","Path":"1296400"}]},"SocialMediaContent":null,"GiftCardStyleList":null,"FlowerSetting":null,"IsShowAutoParts":false,"SponsoredItems":null,"ItemDetail":{"Intelligence":{"Intelligence":null,"TransactionNumber":0,"IntroductionVisible":1,"IntroductionText":"Introduction","IntroductionImage":null,"Introduction":"\u003Cdiv id=\"wc-power-page\"\u003E\u003C\u002Fdiv\u003E\u003Cscript type=\"text\u002Fjavascript\" provider=\"Webcollage\"\u003E(function(){    var loadContent = function () {        window.Webcollage.loadContent(            \"newegg\",            \"9SIANZYBGY3020\",            { reload: true }        );    };    if (window.Webcollage) {        loadContent();    } else {        var script = document.createElement('script');         script.type = 'text\u002Fjavascript';        script.async = true;         script.src = \"https:\u002F\u002Fscontent.webcollage.net\u002Fapi\u002Fv2\u002Fproduct-content\";        if (script.addEventListener) script.addEventListener('load', loadContent);        if (script.attachEvent) script.attachEvent('onload', loadContent);        document.head.appendChild(script);    }}());\u003C\u002Fscript\u003E","IntroductionParagraph1":null,"IntroductionParagraph2":null,"IntroductionParagraph3":null,"HighlightsVisible":0,"HighlightsText":null,"PhotoGalleryVisible":0,"PhotoGalleryText":null,"QuickSpecVisible":0,"QuickSpecText":null,"QuickSpecList":null,"TPCode":null,"HighLightInfoList":null,"ItemIntelligenceList":null,"CategoryIntelligenceInfo":null,"MobileAppFriendly":true},"Warranty":{"WarrantySummary":"We want to ensure your holiday shopping this year is hassle-free. That&rsquo;s why we&rsquo;re automatically extending our return policies on almost every product! For purchases placed between November 1, 2022 and December 25, 2022 you will have until January 31, 2023 to return your product. There&#39;s nothing additional that you have to do!\n\u003Cul\u003E\n\t\u003Cli\u003EReturn for refund until: January 31, 2023\u003C\u002Fli\u003E\n\t\u003Cli\u003EReturn for replacement until: January 31, 2023\u003C\u002Fli\u003E\n\u003C\u002Ful\u003E","WarrantyDayParts":1095,"WarrantyDayLabor":1095,"CustomerServicePhone":"1-646-454-3200","SupportEMail":"","SupportURL":"https:\u002F\u002Fsupport.logi.com\u002Fhc\u002Fen-us\u002F","Is3Party":"0","ServiceProvider":null,"ProviderSupportEmail":null,"ProviderSupportURL":null,"ProviderCustomerServicePhone":null,"Refundable":0,"RMARefundDay":"73","RMAReplacementDay":"73","RestockingFeeRate":0,"WHIWarranty":null,"WarrantyID":10053,"WarrantyName":"Extended Holiday Return Policy"},"Preview":{"TentoeCode":null,"NewTentoeFlag":null,"WebCollageID":null,"IsNewTentoeCode":false,"HasTentoe":false,"HasWebCollage":false,"HasEasy2":false},"DetailSpecification":"\u003CLongDescription Name=\"Detailed Specifications\"\u003E\u003CGroup GroupName=\"\"\u003E\u003CProperty Key=\"Best Seller Ranking\" Value=\"#2 in &lt;a {$BestSellingURL} class=&quot;link-text&quot;&gt;Gaming Headsets&lt;\u002Fa&gt;\" \u002F\u003E\u003C\u002FGroup\u003E\u003CGroup Group ...

# %% [markdown]
# ## Locating Text
#
# Say we want to know the price of the goods sold on the page. We can locate it by using `.find_all(text = '<special_keyword>)'`

# %%
prices = doc.find_all(text = '$')
print(prices)
# Out:
# ['$', '$']

# %% [markdown]
# That's not really helpful since we want to get the entire things, that is the actual price. To get there, we need to know the concept of Beautiful Soup Tree Structure. Then we will use the dollar sign above to get what the actual price is.

# %% [markdown]
# ## Beautiful Soup Tree Structure

# %% [markdown]
# In Beautiful Soup, everything is in tree-like structure, similar to any HTML document

# %%
parent = prices[0].parent
print(parent)
# Out:
# <li class="price-current"><span class="price-current-label"></span>$<strong>119</strong><sup>.99</sup></li>

# %% [markdown]
# Notice that the parent for `$` is the `<li>` tag. Here, we can go to the tag `<strong>` to get access to the price.

# %%
strong = parent.find('strong')
print(strong.string)
# Out:
# 119

# %% [markdown]
# We can also use `.stripped_strings` to get all the contents inside the `<li>` tag.

# %%
value = list(parent.stripped_strings)
print(value)
value = ''.join(value)
print(value)
# Out:
# ['$', '119', '.99']
# $119.99
