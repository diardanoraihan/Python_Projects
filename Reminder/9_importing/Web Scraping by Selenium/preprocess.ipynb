# %% [markdown]
# # Geocode Tourism Destination Spot
#
# Table of Contents:
# 1. Open Scrapped Data from CHSE Kemenparekraf (.txt file to dict object to pandas dataframe)
# 2. Geocode via Google Maps API
# 3. Save the Result to odtw_chse.xlsx

# %% [markdown]
# ### 1. Open Scrapped Data from CHSE Kemenparekraf (.txt file to dict object to pandas dataframe)

# %%
import ast
import pandas as pd
with open('scrapped_data.txt', 'r') as file:
  data = file.read()
  
# Konversi string menjadi dictionary
try:
    dictionary = ast.literal_eval(data)  # Lebih aman daripada eval()
    print(dictionary)
except Exception as e:
    print(f"Error: {e}")
# Out:
# {'objek_wisata': ['Taman Langit Pangalengan 360', 'BRIS WATERPARK', 'Objek Wisata Alam Telaga Biru Cicerem', 'Wisata Alam Sevillage', 'Balong Girang Cigugur', 'The Jungle Waterpark Bogor', 'POKDARWIS TJIKAHOERIPAN GEBIED', 'Taman Cecenet', 'Wana Wisata Ciputrawangi', 'Kuntum Farmfield', 'Taman Lembah Dewata', 'KAMODJAN FILLAGE', 'Wot Batu', 'Cipadayungan', 'Wisata Kampoeng Ciherang', 'Wisata Pesona Taman Puspa', 'Wisata Tanjung Duriat', 'Wisata Puncak Damar', 'Wisata Cipacet', 'Kamojang Ecopark', 'Obyek Wisata BATU LAWANG', 'TWA. Gunung Tangkuban Perahu', 'Fairy Garden by The Lodge', 'Kiara Artha Park', 'OASE SWIMMING CLUB', 'Go! Wet Waterpark', 'Kebun Raya Cibodas (PT. MITRA NATURA RAYA)', 'Sari Ater Hot Springs Ciater', 'Taman Batu Hanjuang', 'Wisata Air Terjun', 'Kolam Renang Nirwana Sports Club', 'Tirta Agung Mas', 'WISATA ALAM GUNUNG DAGO', 'Cikuluwung River Tubing', 'Asstro Highlands Ciater', 'Wisata Alam Citumang', 'Zam Zam Pool', 'FUNPARK Vila Bogor Indah', 'ODTWA Cipaniis', 'Balong Dalem', 'SITUGUNUNG SUSPENSION BRIDGE', 'Wana Wisata Curug Cilember', 'KEBUN RAYA BOGOR (PT. MITRA NATURA RAYA)', 'Destinasi Pantai Pangandaran', 'JATINANGOR NATIONAL PARK', 'WW KAWAH PUTIH', 'DESTINASI PANTAI BATUKARAS', 'Taman Wisata Bougenville', 'DESTINASI PANTAI BATU HIU', 'DESTINASI PANTAI KARAPYAK', 'PUJANGGA MANIK BATU LUHUR', 'Daya Tarik Wisata J&J', 'DESTINASI GREEN CANYON', 'KOLAM RENANG CIMALATI', 'SENTUL ECO EDU TOURISM FOREST', 'Yasmin Centre', 'BUPER CITAMIANG', 'Waduk Darma', 'Ecopark Curugtilu', 'Nuart Sculpture Park', 'TWA LINGGARJATI', 'Pemandian Alam', 'Jurang Landung Curug Landung', 'Glamping Lakeside Rancabali', 'Wana Wisata Galunggung', 'Wana Wisata Curug Cilember', 'Kawah Galunggung', 'TAMAN NASIONAL GUNUNG HALIMUN SALAK NEW CIPUTRI', 'Cipanas Galunggung', 'WAHANA EDUKASI SUKAHAJI WATERBOOM', 'Caringin Pasir Cariu', 'Daya Tarik Wisata Goa Lanang', 'Agro Eduwisata Organik Mulyaharja', 'Theme Park Trans Studio Bandung', 'Kolam Renang Cijoho Indah', 'Jati Sewu Cibungbang', 'WANA WISATA POKLAND', 'Hutan Hujan Sentul', 'Dago Dreampark', 'Objek Wisata Situ Lengkong Panjalu', 'Farmhouse Susu Lembang', 'Industri Makanan Olahan/ Wisata Pabrik Dodol Garut', 'Wana Wisata Puncak Bintang', 'Lembang Park Zoo', 'Wisata PAL 16', 'Ciwayang Body Rafting', 'Sangkan Resort Aqua Park', 'Antapura De Djati', 'WATER KINGDOM MEKARSARI', 'The Great Asia Africa', 'THE LODGE MARIBAYA', 'Ekowisata Mangrove Caplok Barong Ambulu', 'Sanggar Budaya', 'Wisata Sawah Lope', 'Wisata Edukasi Perikanan', 'Taman Buah Mekarsari', 'Wana Wisata Batu Kuda', 'TAMAN BUDAYA SENTUL CITY', 'Kebun Wisata Pasirmukti', 'PT Taman Safari Indonesia', 'The Ranch Cisarua Puncak', 'Orchid Forest Cikole', 'Wisata Bunga dan Kuliner', 'Curug Cipamingkis', 'KARANG SETRA WATERLAND', 'Ranca Cangkuang', 'BATUNUNGGAL INDAH CLUB', 'LITTLE VENICE', 'Taman Satwa Cikembulan', 'Bird Bromelia Pavilion', 'Green Lake View Waterpark', 'Wisata alam curug cipeuteuy', 'Cadas Gantung dan Camping Ground Arya Kamuning', 'Objek Wisata Teras Cibulakan', 'ODTWA Tenjolayar', 'Floating Market Lembang', 'Karnival (Karawang Night Festival)', 'TAMAN BATU PURWAKARTA', 'Jbound', 'Devoyage', 'Wana Wisata Cibolang', 'Sarae Hills', 'Batik Pajampangan', 'Wisata Alam Palalangon Park', 'MUARA JAMBU RECREATION AND CAMP', 'd`Atlantic Water Sports', 'Terminal Wisata Grafika Cikole', 'Marcopolo Water Adventure', 'Wana Wisata Kampung Cai Ranca Upas', 'TRANS STUDIO THEME PARK CIBUBUR', 'Kuya Maranggi Waterpark', 'Agrowisata Gunung Mas PTPN VIII', 'Taman Wisata Alam Gunung Papandayan', 'Taman Wisata Alam Capolaga', 'Green Hill Park', 'Wana Wisata Gunung Puntang', 'KBM Ekowisata Perum Perhutani Jawa Barat & Banten (Wana Wisata Kawah Putih)', 'TAMAN BUNGA NUSANTARA', 'Leuwihejo Riverside', 'Kampung Karuhun Eco Green Park', 'PEMANDIAN AIR PANAS ALAMI WALINI', 'DTWA CIBULAN'], 'alamat': ['TAMAN LANGIT Pangalengan ( Panoramic and Cllamp Ground ), Jalan Cukul, Sukaluyu, Bandung, Jawa Barat, Indonesia', 'BRIS WATERPARK, Raya  ...

# %%
df = pd.DataFrame(dictionary)
df
# Out:
#                               objek_wisata  \
# 0             Taman Langit Pangalengan 360
# 1                           BRIS WATERPARK
# 2    Objek Wisata Alam Telaga Biru Cicerem
# 3                    Wisata Alam Sevillage
# 4                    Balong Girang Cigugur
# ..                                     ...
# 137                  TAMAN BUNGA NUSANTARA
# 138                    Leuwihejo Riverside
# 139         Kampung Karuhun Eco Green Park
# 140       PEMANDIAN AIR PANAS ALAMI WALINI
# 141                           DTWA CIBULAN
#
#                                                 alamat    provinsi  \
# 0    TAMAN LANGIT Pangalengan ( Panoramic and Cllam...  JAWA BARAT
# 1    BRIS WATERPARK, Raya Sukabumi - Cianjur Kampun...  JAWA BARAT
# 2    Telaga Biru Cicerem, Kaduela, Kuningan Regency...  JAWA BARAT
# 3    Wisata Alam Sevillage, Ciloto, Cianjur Regency...  JAWA BARAT
# 4    2FJ4+QJ Cigugur, Kabupaten Kuningan, Jawa Bara...  JAWA BARAT
# ..                                                 ...         ...
# 137  JL. Mariwati km 7 Desa Kawungluwuk Kecamatan S...  JAWA BARAT
# 138  Kampung Wangun Cileungsi RT 01 RW 011 Keluraha...  JAWA BARAT
# 139                                Jl.Pagerbetis KM.09  JAWA BARAT
# 140      Jl. Raya Ciwidey - Patengan Tenjolaya Ciwidey  JAWA BARAT
# 141  Jln Raya Maniskidul Dusun IV Rt.019 Rw.004 Des...  JAWA BARAT
#
#           kab_kota         kecamatan          desa
# 0     KAB. BANDUNG       Pangalengan      Sukaluyu
# 1     KAB. CIANJUR     Warungkondang       Ciwalen
# 2    KAB. KUNINGAN         Pasawahan       Kaduela
# 3     KAB. CIANJUR           Cipanas        Ciloto
# 4    KAB. KUNINGAN           Cigugur       Cigugur
# ..             ...               ...           ...
# 137   KAB. CIANJUR         Sukaresmi   Kawungluwuk
# 138     KAB. BOGOR    Babakan Madang  Karangtengah
# 139  KAB. SUMEDANG  Sumedang Selatan      Citengah
# 140   KAB. BANDUNG         Rancabali      Patengan
# 141  KAB. KUNINGAN         Jalaksana   Manis Kidul
#
# [142 rows x 6 columns]

# %% [markdown]
# ### 2. Geocode via Google Maps API

# %%
from dotenv import load_dotenv
import numpy as np
import googlemaps
import os

# Load .env file
load_dotenv()

# Masukkan API Key Anda
GOOGLE_MAPS_API_KEY = os.getenv("GOOGLE_MAPS_API_KEY")
gmaps = googlemaps.Client(key=GOOGLE_MAPS_API_KEY)

# Fungsi untuk geocoding menggunakan Google Maps API
def geocode_address(address):
    try:
        geocode_result = gmaps.geocode(address)
        if geocode_result:
            location = geocode_result[0]['geometry']['location']
            return location['lat'], location['lng']
        else:
            return None, None
    except Exception as e:
        print(f"Error geocoding {address}: {e}")
        return None, None
    
# define empty lists
lat = []
lon = []
for alamat in df['alamat_detail']:
    # fetch the location coordinate
    loc = geocode_address(alamat)
    # if the coordinate could not be identified
    if loc is None:
        lat.append(np.nan)
        lon.append(np.nan)
    # otherwise
    else:
        lat.append(loc[0])
        lon.append(loc[1])

# store the coordinate data by updating the locations data frame
df['latitude'] = lat
df['longitude'] = lon
print('Shape of the data:', df.shape)
print('Missing values:\n{}'.format(df.isna().sum()))
print('The first 5 rows of the data:')
df.head()
# Out:
#  API queries_quota: 60
#
# Shape of the data: (142, 9)
# Missing values:
# objek_wisata     0
# alamat           2
# provinsi         0
# kab_kota         0
# kecamatan        0
# desa             0
# alamat_detail    0
# latitude         0
# longitude        0
# dtype: int64
# The first 5 rows of the data:
#                             objek_wisata  \
# 0           Taman Langit Pangalengan 360
# 1                         BRIS WATERPARK
# 2  Objek Wisata Alam Telaga Biru Cicerem
# 3                  Wisata Alam Sevillage
# 4                  Balong Girang Cigugur
#
#                                               alamat    provinsi  \
# 0  TAMAN LANGIT Pangalengan ( Panoramic and Cllam...  JAWA BARAT
# 1  BRIS WATERPARK, Raya Sukabumi - Cianjur Kampun...  JAWA BARAT
# 2  Telaga Biru Cicerem, Kaduela, Kuningan Regency...  JAWA BARAT
# 3  Wisata Alam Sevillage, Ciloto, Cianjur Regency...  JAWA BARAT
# 4  2FJ4+QJ Cigugur, Kabupaten Kuningan, Jawa Bara...  JAWA BARAT
#
#         kab_kota      kecamatan      desa  \
# 0   KAB. BANDUNG    Pangalengan  Sukaluyu
# 1   KAB. CIANJUR  Warungkondang   Ciwalen
# 2  KAB. KUNINGAN      Pasawahan   Kaduela
# 3   KAB. CIANJUR        Cipanas    Ciloto
# 4  KAB. KUNINGAN        Cigugur   Cigugur
#
#                                        alamat_detail  latitude   longitude
# 0  Taman Langit Pangalengan 360, Sukaluyu, Pangal... -7.231413  107.526479
# 1  BRIS WATERPARK, Ciwalen, Warungkondang, KAB. C... -6.858775  107.108552
# 2  Objek Wisata Alam Telaga Biru Cicerem, Kaduela... -6.797796  108.423092
# 3  Wisata Alam Sevillage, Ciloto, Cipanas, KAB. C... -6.715240  106.999393
# 4  Balong Girang Cigugur, Cigugur, Cigugur, KAB. ... -6.967765  108.456496

# %% [markdown]
# ### 3. Save the Result to odtw_chse.xlsx

# %%
df.to_excel('/Users/diardanoraihan/Work/GITHUB/Python_Projects/Reminder/9_importing/Web Scraping by Selenium/odtw_chse.xlsx', index=False)
# Out:
# /var/folders/vm/3txrml4d02zch5_v8m3tqwnr0000gp/T/ipykernel_9566/3645964864.py:1: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.1' currently installed).
#   df.to_excel('/Users/diardanoraihan/Work/GITHUB/Python_Projects/Reminder/9_importing/Web Scraping by Selenium/odtw_chse.xlsx', index=False)
