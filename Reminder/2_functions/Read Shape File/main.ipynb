# %%
import pandas as pd
from read_shapefile import read_shapefile

# %%
dataset = 'BATAS DESA DESEMBER 2019 DUKCAPIL JAWA BARAT/BATAS_DESA_DESEMBER_2019_DUKCAPIL_JAWA_BARAT.shp'
df = read_shapefile(dataset)
df.head()
# Out:
#    OBJECT_ID   KODE_DESA          DESA      KODE    PROVINSI    KAB_KOTA  \
# 0    28819.0  3209252008   KARANGANYAR  320925.0  JAWA BARAT     CIREBON
# 1    25683.0  3201032013     HAMBALANG  320103.0  JAWA BARAT       BOGOR
# 2    26492.0  3203032002        CIHAUR  320303.0  JAWA BARAT     CIANJUR
# 3    30348.0  3214172010    SUMBERSARI  321417.0  JAWA BARAT  PURWAKARTA
# 4    26607.0  3203122008  CIRAMAGIRANG  320312.0  JAWA BARAT     CIANJUR
#
#        KECAMATAN    DESA_KELUR  JUMLAH_PEN  JUMLAH_KK  ...  PERANG_  KEPALA_  \
# 0     PANGURAGAN   KARANGANYAR      3629.0     1324.0  ...      1.0      0.0
# 1      CITEUREUP     HAMBALANG     10876.0     3686.0  ...      2.0      1.0
# 2        CIBEBER        CIHAUR      6251.0     2249.0  ...      0.0      0.0
# 3     KIARAPEDES    SUMBERSARI      1905.0      687.0  ...      8.0      1.0
# 4  CIKALONGKULON  CIRAMAGIRANG      3922.0     1360.0  ...      1.0      0.0
#
# ...
